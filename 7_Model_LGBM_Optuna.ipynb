# %% [markdown]
# # Gradient Boosted Tree Model with Light GBM
# using Optuna

# %%
import pandas as pd
import numpy as np
import optuna
import optunahub
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder, TargetEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_auc_score
import lightgbm as lgb

# %% [markdown]
# **Note:** Light GBM can't work with Polars

# %% [markdown]
# ## ingesting data as categorical to LGBM in this section

# %%
X = pd.read_csv("Data/training_set_features.csv", index_col="respondent_id")

# %%
X=X[:].astype("category")

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26707 entries, 0 to 26706
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   h1n1_concern                 26615 non-null  category
#  1   h1n1_knowledge               26591 non-null  category
#  2   behavioral_antiviral_meds    26636 non-null  category
#  3   behavioral_avoidance         26499 non-null  category
#  4   behavioral_face_mask         26688 non-null  category
#  5   behavioral_wash_hands        26665 non-null  category
#  6   behavioral_large_gatherings  26620 non-null  category
#  7   behavioral_outside_home      26625 non-null  category
#  8   behavioral_touch_face        26579 non-null  category
#  9   doctor_recc_h1n1             24547 non-null  category
#  10  doctor_recc_seasonal         24547 non-null  category
#  11  chronic_med_condition        25736 non-null  category
#  12  child_under_6_months         25887 non-null  category
#  13  health_worker                25903 non-null  category
#  14  health_insurance             14433 non-null  category
#  15  opinion_h1n1_vacc_effective  26316 non-null  category
#  16  opinion_h1n1_risk            26319 non-null  category
#  17  opinion_h1n1_sick_from_vacc  26312 non-null  category
#  18  opinion_seas_vacc_effective  26245 non-null  category
#  19  opinion_seas_risk            26193 non-null  category
#  20  opinion_seas_sick_from_vacc  26170 non-null  category
#  21  age_group                    26707 non-null  category
#  22  education                    25300 non-null  category
#  23  race                         26707 non-null  category
#  24  sex                          26707 non-null  category
#  25  income_poverty               22284 non-null  category
#  26  marital_status               25299 non-null  category
#  27  rent_or_own                  24665 non-null  category
#  28  employment_status            25244 non-null  category
#  29  hhs_geo_region               26707 non-null  category
#  30  census_msa                   26707 non-null  category
#  31  household_adults             26458 non-null  category
#  32  household_children           26458 non-null  category
#  33  employment_industry          13377 non-null  category
#  34  employment_occupation        13237 non-null  category
# dtypes: category(35)
# memory usage: 1.1 MB

# %%
y1 = pd.read_csv("Data/training_set_labels.csv", index_col="respondent_id", usecols=["respondent_id", "h1n1_vaccine"])
y2 = pd.read_csv("Data/training_set_labels.csv", index_col="respondent_id", usecols=["respondent_id", "seasonal_vaccine"])

X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y1, test_size=0.2, random_state=42, stratify=y1)
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y2, test_size=0.2, random_state=42, stratify=y2)

# %% [markdown]
# y1: h1n1 labels
#
# y2: seasonal labels

# %%
# First set-up Optuna function
#def objective(trial, X_train, y_train, X_test, y_test):
def objective_h1n1(trial):

    X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y1, test_size=0.2, random_state=42, stratify=y1)
    #X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y2, test_size=0.2, random_state=42, stratify=y2)

    dtrain = lgb.Dataset(X_train1, label=y_train1)
    dvalid = lgb.Dataset(X_test1, label=y_test1)

    params = {
        'objective': 'binary', # i the previous 2 files I didn't explicitly define this, as LGBM would use this as default for the classifier
        'metric': 'auc',
        'verbosity': -1,
        'max_depth': trial.suggest_int('max_depth', 1, 6),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 1.0, log=False),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'subsample_freq': trial.suggest_int('subsample_freq', 0, 10),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        'min_child_weight': trial.suggest_float('min_child_weight', 0.001, 100, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-9, 10.0, log=True), # in LGBM; the value is not limited to [0 to 1] also knwon as lambda_l1
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-9, 10.0, log=True), # in LGBM ; the value is not limited to [0 to 1] also knwon as lambda_l2
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "random_state": 8
    }

    # a callback for pruning
    pruning_callback = optuna.integration.LightGBMPruningCallback(trial, 'auc')
    model = lgb.train(params,
                      dtrain,
                      valid_sets=[dvalid],
                      callbacks=[pruning_callback],)
    
    preds = model.predict(X_test1)
    return roc_auc_score(y_test1, preds)

def objective_seas(trial):

    #X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y1, test_size=0.2, random_state=42, stratify=y1)
    X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y2, test_size=0.2, random_state=42, stratify=y2)

    dtrain = lgb.Dataset(X_train2, label=y_train2)
    dvalid = lgb.Dataset(X_test2, label=y_test2)

    params = {
        'objective': 'binary', # i the previous 2 files I didn't explicitly define this, as LGBM would use this as default for the classifier
        'metric': 'auc',
        'verbosity': -1,
        'max_depth': trial.suggest_int('max_depth', 1, 6),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 1.0, log=False),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'subsample_freq': trial.suggest_int('subsample_freq', 0, 10),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        'min_child_weight': trial.suggest_float('min_child_weight', 0.001, 100, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-9, 10.0, log=True), # in LGBM; the value is not limited to [0 to 1] also knwon as lambda_l1
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-9, 10.0, log=True), # in LGBM ; the value is not limited to [0 to 1] also knwon as lambda_l2
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "random_state": 8
    }

    # a callback for pruning
    pruning_callback = optuna.integration.LightGBMPruningCallback(trial, 'auc')
    model = lgb.train(params,
                      dtrain,
                      valid_sets=[dvalid],
                      callbacks=[pruning_callback])
    
    preds = model.predict(X_test2)
    return roc_auc_score(y_test2, preds)

# %%
#module = optunahub.load_module(package="samplers/auto_sampler")
study = optuna.create_study(direction='maximize', 
                            pruner=optuna.pruners.MedianPruner(), # Ist der Pruner wirklich eine gute Idee?
#                            sampler=module.AutoSampler(),
                            ) 
study.optimize(objective_h1n1, n_trials = 100) # Wo ist die eingabe für K-Fold CV =5?
# Out:
# [I 2024-11-27 12:13:29,316] A new study created in memory with name: no-name-65edb4a6-61e3-4952-beed-69d5b31e5815
# [I 2024-11-27 12:13:29,734] Trial 0 finished with value: 0.8567087160166242 and parameters: {'max_depth': 6, 'learning_rate': 0.21407078573434835, 'subsample': 0.9522106535780931, 'subsample_freq': 7, 'colsample_bytree': 0.6318424998276143, 'min_child_samples': 77, 'min_child_weight': 0.017305700756464478, 'reg_alpha': 5.766175957779647e-08, 'reg_lambda': 7.871954880887852e-06, 'num_leaves': 50}. Best is trial 0 with value: 0.8567087160166242.
# [I 2024-11-27 12:13:30,070] Trial 1 finished with value: 0.8194437841692417 and parameters: {'max_depth': 1, 'learning_rate': 0.009456920848839128, 'subsample': 0.2913940398886474, 'subsample_freq': 0, 'colsample_bytree': 0.973187330236381, 'min_child_samples': 81, 'min_child_weight': 2.184232370275735, 'reg_alpha': 1.8045736335068904e-06, 'reg_lambda': 8.894824644771073e-05, 'num_leaves': 211}. Best is trial 0 with value: 0.8567087160166242.
# [I 2024-11-27 12:13:30,447] Trial 2 finished with value: 0.8566737417917902 and parameters: {'max_depth': 2, 'learning_rate': 0.6520727403428463, 'subsample': 0.9397433931759576, 'subsample_freq': 2, 'colsample_bytree': 0.3460875831129625, 'min_child_samples': 53, 'min_child_weight': 0.022428477169086414, 'reg_alpha': 3.086739444184482e-09, 'reg_lambda': 3.7559447915996373, 'num_leaves': 221}. Best is trial 0 with value: 0.8567087160166242.
# [I 2024-11-27 12:13:30,833] Trial 3 finished with value: 0.8258815546566505 and parameters: {'max_depth': 6, 'learning_rate': 0.8618156422293755, 'subsample': 0.6597699405789345, 'subsample_freq': 4, 'colsample_bytree': 0.9821812361758451, 'min_child_samples': 64, 'min_child_weight': 53.94698176698664, 'reg_alpha': 0.056557368209311926, 'reg_lambda': 0.066271622776346, 'num_leaves': 121}. Best is trial 0 with value: 0.8567087160166242.
# [I 2024-11-27 12:13:31,202] Trial 4 finished with value: 0.8523492940756385 and parameters: {'max_depth': 1, 'learning_rate': 0.7221092753813128, 'subsample': 0.5667229110260483, 'subsample_freq': 1, 'colsample_bytree': 0.2597742518738416, 'min_child_samples': 68, 'min_child_weight': 0.29084093693182256, 'reg_alpha': 0.07847804404390658, 'reg_lambda': 9.970246214510052e-05, 'num_leaves': 215}. Best is trial 0 with value: 0.8567087160166242.
# [I 2024-11-27 12:13:31,380] Trial 5 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:31,487] Trial 6 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:31,595] Trial 7 pruned. Trial was pruned at iteration 1.
# [I 2024-11-27 12:13:31,695] Trial 8 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:31,816] Trial 9 pruned. Trial was pruned at iteration 7.
# [I 2024-11-27 12:13:31,962] Trial 10 pruned. Trial was pruned at iteration 8.
# [I 2024-11-27 12:13:32,097] Trial 11 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:32,329] Trial 12 pruned. Trial was pruned at iteration 34.
# [I 2024-11-27 12:13:32,452] Trial 13 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:32,600] Trial 14 pruned. Trial was pruned at iteration 7.
# [I 2024-11-27 12:13:32,730] Trial 15 pruned. Trial was pruned at iteration 2.
# [I 2024-11-27 12:13:32,895] Trial 16 pruned. Trial was pruned at iteration 8.
# [I 2024-11-27 12:13:33,029] Trial 17 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:33,167] Trial 18 pruned. Trial was pruned at iteration 8.
# [I 2024-11-27 12:13:33,313] Trial 19 pruned. Trial was pruned at iteration 8.
# [I 2024-11-27 12:13:33,438] Trial 20 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:33,556] Trial 21 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:33,677] Trial 22 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:33,791] Trial 23 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:33,915] Trial 24 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:34,042] Trial 25 pruned. Trial was pruned at iteration 2.
# [I 2024-11-27 12:13:34,189] Trial 26 pruned. Trial was pruned at iteration 7.
# [I 2024-11-27 12:13:34,310] Trial 27 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:34,716] Trial 28 finished with value: 0.8455098435688787 and parameters: {'max_depth': 5, 'learning_rate': 0.8180922728754201, 'subsample': 0.9257098726779557, 'subsample_freq': 6, 'colsample_bytree': 0.33912455923455265, 'min_child_samples': 69, 'min_child_weight': 6.596633884069293, 'reg_alpha': 5.007709775763986, 'reg_lambda': 1.6971576012844304e-08, 'num_leaves': 228}. Best is trial 0 with value: 0.8567087160166242.
# [I 2024-11-27 12:13:34,871] Trial 29 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:34,994] Trial 30 pruned. Trial was pruned at iteration 2.
# [I 2024-11-27 12:13:35,427] Trial 31 finished with value: 0.851589494748107 and parameters: {'max_depth': 5, 'learning_rate': 0.814237476727963, 'subsample': 0.9355842665821724, 'subsample_freq': 6, 'colsample_bytree': 0.33865934092774214, 'min_child_samples': 69, 'min_child_weight': 5.898101775683838, 'reg_alpha': 8.121741593637399, 'reg_lambda': 1.8631212720386104e-08, 'num_leaves': 230}. Best is trial 0 with value: 0.8567087160166242.
# [I 2024-11-27 12:13:35,588] Trial 32 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:35,716] Trial 33 pruned. Trial was pruned at iteration 1.
# [I 2024-11-27 12:13:35,897] Trial 34 pruned. Trial was pruned at iteration 19.
# [I 2024-11-27 12:13:36,050] Trial 35 pruned. Trial was pruned at iteration 7.
# [I 2024-11-27 12:13:36,173] Trial 36 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:36,319] Trial 37 pruned. Trial was pruned at iteration 7.
# [I 2024-11-27 12:13:36,723] Trial 38 finished with value: 0.8468007484902967 and parameters: {'max_depth': 6, 'learning_rate': 0.49797994929013734, 'subsample': 0.7799887381129194, 'subsample_freq': 4, 'colsample_bytree': 0.4486223106240479, 'min_child_samples': 24, 'min_child_weight': 26.05757428148595, 'reg_alpha': 0.2999244213944194, 'reg_lambda': 0.0002536363611359512, 'num_leaves': 222}. Best is trial 0 with value: 0.8567087160166242.
# [I 2024-11-27 12:13:36,884] Trial 39 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:37,014] Trial 40 pruned. Trial was pruned at iteration 4.
# [I 2024-11-27 12:13:37,190] Trial 41 pruned. Trial was pruned at iteration 19.
# [I 2024-11-27 12:13:37,358] Trial 42 pruned. Trial was pruned at iteration 9.
# [I 2024-11-27 12:13:37,478] Trial 43 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:37,895] Trial 44 finished with value: 0.8435079356935 and parameters: {'max_depth': 5, 'learning_rate': 0.610672039075825, 'subsample': 0.9620379185282883, 'subsample_freq': 3, 'colsample_bytree': 0.437575767301659, 'min_child_samples': 13, 'min_child_weight': 4.297266131713589, 'reg_alpha': 0.5934347045701949, 'reg_lambda': 1.567662045810651e-06, 'num_leaves': 179}. Best is trial 0 with value: 0.8567087160166242.
# [I 2024-11-27 12:13:38,086] Trial 45 pruned. Trial was pruned at iteration 10.
# [I 2024-11-27 12:13:38,207] Trial 46 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:38,333] Trial 47 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:38,453] Trial 48 pruned. Trial was pruned at iteration 1.
# [I 2024-11-27 12:13:38,652] Trial 49 pruned. Trial was pruned at iteration 20.
# [I 2024-11-27 12:13:38,774] Trial 50 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:38,913] Trial 51 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:39,042] Trial 52 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:39,173] Trial 53 pruned. Trial was pruned at iteration 2.
# [I 2024-11-27 12:13:39,317] Trial 54 pruned. Trial was pruned at iteration 2.
# [I 2024-11-27 12:13:39,442] Trial 55 pruned. Trial was pruned at iteration 2.
# [I 2024-11-27 12:13:39,562] Trial 56 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:39,682] Trial 57 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:39,807] Trial 58 pruned. Trial was pruned at iteration 1.
# [I 2024-11-27 12:13:39,940] Trial 59 pruned. Trial was pruned at iteration 1.
# [I 2024-11-27 12:13:40,086] Trial 60 pruned. Trial was pruned at iteration 7.
# [I 2024-11-27 12:13:40,513] Trial 61 finished with value: 0.8474062004902674 and parameters: {'max_depth': 5, 'learning_rate': 0.5319383634185629, 'subsample': 0.9639209431362649, 'subsample_freq': 3, 'colsample_bytree': 0.4287930970073657, 'min_child_samples': 12, 'min_child_weight': 3.403013400809737, 'reg_alpha': 0.6550798192783519, 'reg_lambda': 2.2875640853675767e-06, 'num_leaves': 179}. Best is trial 0 with value: 0.8567087160166242.
# [I 2024-11-27 12:13:40,672] Trial 62 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:40,803] Trial 63 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:40,927] Trial 64 pruned. Trial was pruned at iteration 2.
# [I 2024-11-27 12:13:41,046] Trial 65 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:41,177] Trial 66 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:41,308] Trial 67 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:41,437] Trial 68 pruned. Trial was pruned at iteration 1.
# [I 2024-11-27 12:13:41,574] Trial 69 pruned. Trial was pruned at iteration 2.
# [I 2024-11-27 12:13:41,693] Trial 70 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:42,104] Trial 71 finished with value: 0.8406402586836079 and parameters: {'max_depth': 5, 'learning_rate': 0.6271296394138797, 'subsample': 0.9516707812892856, 'subsample_freq': 3, 'colsample_bytree': 0.44445741298665203, 'min_child_samples': 13, 'min_child_weight': 3.640430858787607, 'reg_alpha': 0.6196310950505561, 'reg_lambda': 4.6803031022433786e-08, 'num_leaves': 155}. Best is trial 0 with value: 0.8567087160166242.
# [I 2024-11-27 12:13:42,554] Trial 72 finished with value: 0.8457131966965066 and parameters: {'max_depth': 5, 'learning_rate': 0.5820562415348275, 'subsample': 0.971642005342324, 'subsample_freq': 3, 'colsample_bytree': 0.4247093663749367, 'min_child_samples': 8, 'min_child_weight': 5.408279364173468, 'reg_alpha': 0.14795022592567855, 'reg_lambda': 2.183362077603102e-06, 'num_leaves': 182}. Best is trial 0 with value: 0.8567087160166242.
# [I 2024-11-27 12:13:42,714] Trial 73 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:42,851] Trial 74 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:42,977] Trial 75 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:43,105] Trial 76 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:43,228] Trial 77 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:43,361] Trial 78 pruned. Trial was pruned at iteration 5.
# [I 2024-11-27 12:13:43,495] Trial 79 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:43,615] Trial 80 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:43,737] Trial 81 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:44,154] Trial 82 finished with value: 0.8418471835801251 and parameters: {'max_depth': 5, 'learning_rate': 0.6239933541971726, 'subsample': 0.9133958289134756, 'subsample_freq': 3, 'colsample_bytree': 0.4503716408278323, 'min_child_samples': 5, 'min_child_weight': 4.858124921836459, 'reg_alpha': 0.9068488100706712, 'reg_lambda': 7.322175679450654e-07, 'num_leaves': 176}. Best is trial 0 with value: 0.8567087160166242.
# [I 2024-11-27 12:13:44,310] Trial 83 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:44,439] Trial 84 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:44,594] Trial 85 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:44,721] Trial 86 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:44,858] Trial 87 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:44,993] Trial 88 pruned. Trial was pruned at iteration 4.
# [I 2024-11-27 12:13:45,118] Trial 89 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:45,238] Trial 90 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:45,657] Trial 91 finished with value: 0.8387210742741539 and parameters: {'max_depth': 5, 'learning_rate': 0.6249898962982737, 'subsample': 0.9084932462445354, 'subsample_freq': 3, 'colsample_bytree': 0.4590515102064891, 'min_child_samples': 6, 'min_child_weight': 5.875757790008862, 'reg_alpha': 0.9831483213212887, 'reg_lambda': 8.241354113617223e-07, 'num_leaves': 180}. Best is trial 0 with value: 0.8567087160166242.
# [I 2024-11-27 12:13:45,820] Trial 92 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:45,957] Trial 93 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:46,095] Trial 94 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:46,218] Trial 95 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:46,347] Trial 96 pruned. Trial was pruned at iteration 2.
# [I 2024-11-27 12:13:46,474] Trial 97 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:46,601] Trial 98 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:46,726] Trial 99 pruned. Trial was pruned at iteration 0.

# %%
print("Number of finished trials: {}".format(len(study.trials)))
print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Number of finished trials: 100
# Best trial:
#   Value: 0.8567087160166242
#   Params:
#     max_depth: 6
#     learning_rate: 0.21407078573434835
#     subsample: 0.9522106535780931
#     subsample_freq: 7
#     colsample_bytree: 0.6318424998276143
#     min_child_samples: 77
#     min_child_weight: 0.017305700756464478
#     reg_alpha: 5.766175957779647e-08
#     reg_lambda: 7.871954880887852e-06
#     num_leaves: 50

# %%
#module = optunahub.load_module(package="samplers/auto_sampler")
study2 = optuna.create_study(direction='maximize', 
                            pruner=optuna.pruners.MedianPruner(), # Ist der Pruner wirklich eine gute Idee?
                            #sampler=module.AutoSampler(),
                            ) 
study2.optimize(objective_seas, n_trials = 100) # Wo ist die eingabe für K-Fold CV =5?
# Out:
# [I 2024-11-27 12:13:46,750] A new study created in memory with name: no-name-2826a8a5-d62a-45bb-be91-7e4146c0ad9e
# [I 2024-11-27 12:13:47,099] Trial 0 finished with value: 0.8519409862986302 and parameters: {'max_depth': 4, 'learning_rate': 0.3121193346359039, 'subsample': 0.41711715583353415, 'subsample_freq': 5, 'colsample_bytree': 0.6759985314730259, 'min_child_samples': 46, 'min_child_weight': 0.07623479570941365, 'reg_alpha': 1.1318169108468219e-06, 'reg_lambda': 1.205286763435109e-09, 'num_leaves': 70}. Best is trial 0 with value: 0.8519409862986302.
# [I 2024-11-27 12:13:47,465] Trial 1 finished with value: 0.8502951600511803 and parameters: {'max_depth': 4, 'learning_rate': 0.4467103113774013, 'subsample': 0.3672571227604582, 'subsample_freq': 7, 'colsample_bytree': 0.41542665829393943, 'min_child_samples': 91, 'min_child_weight': 35.26912643105677, 'reg_alpha': 5.491928942361416e-09, 'reg_lambda': 8.622022116011e-08, 'num_leaves': 170}. Best is trial 0 with value: 0.8519409862986302.
# [I 2024-11-27 12:13:47,814] Trial 2 finished with value: 0.8605522094928655 and parameters: {'max_depth': 2, 'learning_rate': 0.9275232814605117, 'subsample': 0.7023123421847011, 'subsample_freq': 0, 'colsample_bytree': 0.21527381534422632, 'min_child_samples': 9, 'min_child_weight': 0.09093557729094359, 'reg_alpha': 0.0012390629035238404, 'reg_lambda': 6.4798815069316265e-09, 'num_leaves': 137}. Best is trial 2 with value: 0.8605522094928655.
# [I 2024-11-27 12:13:48,164] Trial 3 finished with value: 0.8371733363754219 and parameters: {'max_depth': 3, 'learning_rate': 0.6773881923028621, 'subsample': 0.42601745305559413, 'subsample_freq': 10, 'colsample_bytree': 0.8724976029239498, 'min_child_samples': 91, 'min_child_weight': 0.012509843037303594, 'reg_alpha': 7.866438601618743e-05, 'reg_lambda': 5.819373581112953e-08, 'num_leaves': 129}. Best is trial 2 with value: 0.8605522094928655.
# [I 2024-11-27 12:13:48,513] Trial 4 finished with value: 0.8564675014101348 and parameters: {'max_depth': 2, 'learning_rate': 0.7799908147608414, 'subsample': 0.7195886081639681, 'subsample_freq': 6, 'colsample_bytree': 0.16532911008189563, 'min_child_samples': 83, 'min_child_weight': 4.232069409626325, 'reg_alpha': 0.009058192883185958, 'reg_lambda': 1.5218597952434192e-07, 'num_leaves': 172}. Best is trial 2 with value: 0.8605522094928655.
# [I 2024-11-27 12:13:48,644] Trial 5 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:48,747] Trial 6 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:48,844] Trial 7 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:49,227] Trial 8 finished with value: 0.863914280704497 and parameters: {'max_depth': 6, 'learning_rate': 0.18755832369088704, 'subsample': 0.9558393406367027, 'subsample_freq': 8, 'colsample_bytree': 0.6994378385759924, 'min_child_samples': 40, 'min_child_weight': 59.07655474972175, 'reg_alpha': 5.382162260998821e-09, 'reg_lambda': 5.1883835536972365, 'num_leaves': 130}. Best is trial 8 with value: 0.863914280704497.
# [I 2024-11-27 12:13:49,356] Trial 9 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:49,479] Trial 10 pruned. Trial was pruned at iteration 3.
# [I 2024-11-27 12:13:49,599] Trial 11 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:49,714] Trial 12 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:49,829] Trial 13 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:49,954] Trial 14 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:50,069] Trial 15 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:50,200] Trial 16 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:50,322] Trial 17 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:50,438] Trial 18 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:50,584] Trial 19 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:50,699] Trial 20 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:50,825] Trial 21 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:50,941] Trial 22 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:51,059] Trial 23 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:51,184] Trial 24 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:51,311] Trial 25 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:51,431] Trial 26 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:51,550] Trial 27 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:51,948] Trial 28 finished with value: 0.8513794674514129 and parameters: {'max_depth': 5, 'learning_rate': 0.25499296880806577, 'subsample': 0.6066677684608682, 'subsample_freq': 9, 'colsample_bytree': 0.7596441813822343, 'min_child_samples': 88, 'min_child_weight': 2.8021222509971175, 'reg_alpha': 3.547652646383977e-06, 'reg_lambda': 2.223890884415735e-08, 'num_leaves': 86}. Best is trial 8 with value: 0.863914280704497.
# [I 2024-11-27 12:13:52,354] Trial 29 finished with value: 0.8538962323873986 and parameters: {'max_depth': 4, 'learning_rate': 0.41331670221135264, 'subsample': 0.7957289950813113, 'subsample_freq': 6, 'colsample_bytree': 0.6775332600401502, 'min_child_samples': 43, 'min_child_weight': 0.08023292368595157, 'reg_alpha': 5.3877254424419306e-08, 'reg_lambda': 2.46133140662119e-07, 'num_leaves': 53}. Best is trial 8 with value: 0.863914280704497.
# [I 2024-11-27 12:13:52,505] Trial 30 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:52,885] Trial 31 finished with value: 0.8504772628526481 and parameters: {'max_depth': 4, 'learning_rate': 0.45166819470080444, 'subsample': 0.8084548541226866, 'subsample_freq': 6, 'colsample_bytree': 0.7155292868280505, 'min_child_samples': 46, 'min_child_weight': 0.023651549177682852, 'reg_alpha': 9.912962717412182e-09, 'reg_lambda': 2.5130912827078617e-07, 'num_leaves': 41}. Best is trial 8 with value: 0.863914280704497.
# [I 2024-11-27 12:13:53,036] Trial 32 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:53,162] Trial 33 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:53,586] Trial 34 finished with value: 0.8426212099766422 and parameters: {'max_depth': 6, 'learning_rate': 0.40328292404130045, 'subsample': 0.7856235646990726, 'subsample_freq': 8, 'colsample_bytree': 0.8316536739287166, 'min_child_samples': 64, 'min_child_weight': 0.12927081024322462, 'reg_alpha': 1.0085422089770266e-07, 'reg_lambda': 1.081509783969332e-07, 'num_leaves': 120}. Best is trial 8 with value: 0.863914280704497.
# [I 2024-11-27 12:13:53,741] Trial 35 pruned. Trial was pruned at iteration 1.
# [I 2024-11-27 12:13:53,863] Trial 36 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:53,995] Trial 37 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:54,125] Trial 38 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:54,243] Trial 39 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:54,362] Trial 40 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:54,486] Trial 41 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:54,616] Trial 42 pruned. Trial was pruned at iteration 1.
# [I 2024-11-27 12:13:54,741] Trial 43 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:54,881] Trial 44 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:54,998] Trial 45 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:55,129] Trial 46 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:55,313] Trial 47 pruned. Trial was pruned at iteration 19.
# [I 2024-11-27 12:13:55,438] Trial 48 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:55,562] Trial 49 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:55,683] Trial 50 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:55,816] Trial 51 pruned. Trial was pruned at iteration 4.
# [I 2024-11-27 12:13:55,939] Trial 52 pruned. Trial was pruned at iteration 1.
# [I 2024-11-27 12:13:56,152] Trial 53 pruned. Trial was pruned at iteration 32.
# [I 2024-11-27 12:13:56,286] Trial 54 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:56,410] Trial 55 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:56,532] Trial 56 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:56,656] Trial 57 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:56,812] Trial 58 pruned. Trial was pruned at iteration 12.
# [I 2024-11-27 12:13:56,950] Trial 59 pruned. Trial was pruned at iteration 7.
# [I 2024-11-27 12:13:57,077] Trial 60 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:57,453] Trial 61 finished with value: 0.8512732760265818 and parameters: {'max_depth': 4, 'learning_rate': 0.47627277652467565, 'subsample': 0.8098603304587185, 'subsample_freq': 6, 'colsample_bytree': 0.7314487538778072, 'min_child_samples': 46, 'min_child_weight': 0.03749958627936615, 'reg_alpha': 9.668386359987699e-09, 'reg_lambda': 2.795398693247507e-07, 'num_leaves': 14}. Best is trial 8 with value: 0.863914280704497.
# [I 2024-11-27 12:13:57,612] Trial 62 pruned. Trial was pruned at iteration 1.
# [I 2024-11-27 12:13:57,732] Trial 63 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:57,869] Trial 64 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:57,989] Trial 65 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:58,127] Trial 66 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:58,527] Trial 67 finished with value: 0.846628457470968 and parameters: {'max_depth': 5, 'learning_rate': 0.3744654168427213, 'subsample': 0.6739592279728835, 'subsample_freq': 6, 'colsample_bytree': 0.7345221093099352, 'min_child_samples': 49, 'min_child_weight': 0.7629096665372745, 'reg_alpha': 9.153513083670994e-09, 'reg_lambda': 6.118852815532863e-08, 'num_leaves': 86}. Best is trial 8 with value: 0.863914280704497.
# [I 2024-11-27 12:13:58,680] Trial 68 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:58,805] Trial 69 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:58,928] Trial 70 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:59,052] Trial 71 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:59,424] Trial 72 finished with value: 0.8535720246155667 and parameters: {'max_depth': 4, 'learning_rate': 0.4822597915383894, 'subsample': 0.87217777478131, 'subsample_freq': 6, 'colsample_bytree': 0.7128141584933932, 'min_child_samples': 57, 'min_child_weight': 0.004218928381269954, 'reg_alpha': 1.6246239460808254e-09, 'reg_lambda': 3.6777821994189135e-07, 'num_leaves': 41}. Best is trial 8 with value: 0.863914280704497.
# [I 2024-11-27 12:13:59,585] Trial 73 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:59,708] Trial 74 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:59,831] Trial 75 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:13:59,958] Trial 76 pruned. Trial was pruned at iteration 2.
# [I 2024-11-27 12:14:00,082] Trial 77 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:00,213] Trial 78 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:00,338] Trial 79 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:00,463] Trial 80 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:00,622] Trial 81 pruned. Trial was pruned at iteration 12.
# [I 2024-11-27 12:14:00,743] Trial 82 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:00,867] Trial 83 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:01,008] Trial 84 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:01,139] Trial 85 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:01,549] Trial 86 finished with value: 0.8480006365851992 and parameters: {'max_depth': 5, 'learning_rate': 0.3864736032098831, 'subsample': 0.8103717900375151, 'subsample_freq': 5, 'colsample_bytree': 0.7623631109128193, 'min_child_samples': 52, 'min_child_weight': 0.05628462324955315, 'reg_alpha': 5.017944740467207e-09, 'reg_lambda': 3.720029187052555e-07, 'num_leaves': 55}. Best is trial 8 with value: 0.863914280704497.
# [I 2024-11-27 12:14:01,710] Trial 87 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:01,842] Trial 88 pruned. Trial was pruned at iteration 1.
# [I 2024-11-27 12:14:02,009] Trial 89 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:02,130] Trial 90 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:02,252] Trial 91 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:02,389] Trial 92 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:02,509] Trial 93 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:02,636] Trial 94 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:02,773] Trial 95 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:02,899] Trial 96 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:03,024] Trial 97 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:03,153] Trial 98 pruned. Trial was pruned at iteration 0.
# [I 2024-11-27 12:14:03,286] Trial 99 pruned. Trial was pruned at iteration 0.

# %%
print("Seasonal Vaccination")
print("Number of finished trials: {}".format(len(study2.trials)))
print("Best trial:")
trial = study2.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Seasonal Vaccination
# Number of finished trials: 100
# Best trial:
#   Value: 0.863914280704497
#   Params:
#     max_depth: 6
#     learning_rate: 0.18755832369088704
#     subsample: 0.9558393406367027
#     subsample_freq: 8
#     colsample_bytree: 0.6994378385759924
#     min_child_samples: 40
#     min_child_weight: 59.07655474972175
#     reg_alpha: 5.382162260998821e-09
#     reg_lambda: 5.1883835536972365
#     num_leaves: 130

# %% [markdown]
# y1: h1n1 labels
#
# y2: seasonal labels

# %% [markdown]
# # Submission Data

# %%
dtrain_h1n1 = lgb.Dataset(X_train1, label=y_train1)
dtrain_seas = lgb.Dataset(X_train2, label=y_train2)

# %%
h1n1_model = lgb.LGBMClassifier(**study.best_trial.params)
seas_model = lgb.LGBMClassifier(**study2.best_trial.params)

# %%
h1n1_model.fit(X_train1, np.ravel(y_train1), eval_set=(X_test1, np.ravel(y_test1)), eval_metric='auc')
seas_model.fit(X_train2, np.ravel(y_train2), eval_set=(X_test2, np.ravel(y_test2)), eval_metric='auc')
# Out:
# LGBMClassifier(colsample_bytree=0.6994378385759924,
#                learning_rate=0.18755832369088704, max_depth=6,
#                min_child_samples=40, min_child_weight=59.07655474972175,
#                num_leaves=130, reg_alpha=5.382162260998821e-09,
#                reg_lambda=5.1883835536972365, subsample=0.9558393406367027,
#                subsample_freq=8)

# %%
print('Best score for the H1N1 model')
for key, value in h1n1_model.best_score_.items():
    print(key, value) #h1n1_model.best_score_

print('Best score for the Seasonal model')
for key, value in seas_model.best_score_.items():
    print(key, value) #h1n1_model.best_score_
# Out:
# Best score for the H1N1 model
# valid_0 OrderedDict({'auc': 0.8558783399599367, 'binary_logloss': 0.36107319898878903})
# Best score for the Seasonal model
# valid_0 OrderedDict({'auc': 0.864412704381523, 'binary_logloss': 0.45928310109426146})

# %%
temp_list = list(h1n1_model.best_score_.items())
#temp_list[0][1]
temp_temp_list = list(temp_list[0][1].items())
temp_temp_list[0][1]
print('Best auc score for the H1N1 model:', temp_temp_list[0][1])

temp_list = list(seas_model.best_score_.items())
#temp_list[0][1]
temp_temp_list = list(temp_list[0][1].items())
temp_temp_list[0][1]
print('Best auc score for the Seasonal model:', temp_temp_list[0][1])
# Out:
# Best auc score for the H1N1 model: 0.8558783399599367
# Best auc score for the Seasonal model: 0.864412704381523

# %%
h1n1_model.predict(X_test1)
# Out:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
h1n1_model.predict_proba(X_test1)[:,1]
# Out:
# array([6.72554589e-02, 9.17602226e-01, 5.90640887e-04, ...,
#        4.90199102e-01, 6.13295874e-02, 5.44400991e-03])

# %%
df_test_set_features = pd.read_csv('Data/test_set_features.csv', index_col='respondent_id')
df_test_set_features=df_test_set_features[:].astype("category")

# %%
h1n1_vaccine_probability=h1n1_model.predict_proba(df_test_set_features)
seas_vaccine_probability=seas_model.predict_proba(df_test_set_features)

df_submission = df_test_set_features[[]]
df_submission['h1n1_vaccine'] = h1n1_vaccine_probability[:,1].tolist()
df_submission['seasonal_vaccine'] = seas_vaccine_probability[:,1].tolist()
# Out:
# C:\Users\sager\AppData\Local\Temp\ipykernel_36188\1624343897.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_submission['h1n1_vaccine'] = h1n1_vaccine_probability[:,1].tolist()
# C:\Users\sager\AppData\Local\Temp\ipykernel_36188\1624343897.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_submission['seasonal_vaccine'] = seas_vaccine_probability[:,1].tolist()

# %%
df_submission.to_csv("LGBM_Model/Optuna_submission.csv")
