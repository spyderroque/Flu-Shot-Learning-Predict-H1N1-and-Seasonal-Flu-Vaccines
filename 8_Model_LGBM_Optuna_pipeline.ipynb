# %% [markdown]
# # Gradient Boosted Tree Model with Light GBM
# using Optuna

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ## Conclusion of all files 4_* to 8_*:
# - consider using different samplers for Optuna (not done here)
# - better recreate the pipeline without using a modified objective function overloaded with _study.best_trial_ !

# %%
import pandas as pd
import numpy as np
import optuna
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder, TargetEncoder
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.metrics import roc_auc_score
import lightgbm as lgb

# %%
X = pd.read_csv("Data/training_set_features.csv", index_col="respondent_id")

# %%
y1 = pd.read_csv("Data/training_set_labels.csv", index_col="respondent_id", usecols=["respondent_id", "h1n1_vaccine"])
y2 = pd.read_csv("Data/training_set_labels.csv", index_col="respondent_id", usecols=["respondent_id", "seasonal_vaccine"])

X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y1, test_size=0.2, random_state=42, stratify=y1)
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y2, test_size=0.2, random_state=42, stratify=y2)

# %%
def objective_h1n1(trial):
    
    dtrain = lgb.Dataset(X_train1, label=y_train1)
    dvalid = lgb.Dataset(X_test1, label=y_test1)

    '''First select the encoder'''
    encoders = trial.suggest_categorical("encoders", ["TargetEncoder", "OrdinalEncoder"])

    if encoders == "TargetEncoder":
        encoder = TargetEncoder()
    else:
        encoder = OrdinalEncoder()
    
    '''2nd select the model LGBM-model'''
    # instantiate parameters for classifier
    params = {
        'objective': 'binary', # i the previous 2 files I didn't explicitly define this, as LGBM would use this as default for the classifier
        'metric': 'auc',
        'verbosity': 0,
        'max_depth': trial.suggest_int('max_depth', 1, 6),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 1.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'subsample_freq': trial.suggest_int('subsample_freq', 0, 10),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        'min_child_weight': trial.suggest_float('min_child_weight', 0.001, 100, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-9, 10.0, log=True), # in LGBM; the value is not limited to [0 to 1] also knwon as lambda_l1
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-9, 10.0, log=True), # in LGBM ; the value is not limited to [0 to 1] also knwon as lambda_l2
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "random_state": 8,
        #"n_jobs": 1
    }

    #classifier = lgb.LGBMClassifier(**params, callbacks=[optuna.integration.LightGBMPruningCallback(trial, "auc")])
    classifier = lgb.LGBMClassifier(**params)

    pipe = Pipeline([('encoder', encoder), 
                     ('clf', classifier)])
    pipe.fit(X_train1, np.ravel(y_train1))

    y_pred = pipe.predict_proba(X_test1)[:, 1]
    score = roc_auc_score(y_test1, y_pred)

    return score

# %%
study_h1n1 = optuna.create_study(direction="maximize")#, pruner=optuna.pruners.MedianPruner())
study_h1n1.optimize(objective_h1n1, n_trials=100)
# Out:
# [I 2024-11-27 17:56:41,472] A new study created in memory with name: no-name-f4b6008a-8a42-44f8-90b0-84b97ad323aa
# [I 2024-11-27 17:56:41,671] Trial 0 finished with value: 0.8410105247285571 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 6, 'learning_rate': 0.0639777146421749, 'subsample': 0.8523817819913164, 'subsample_freq': 1, 'colsample_bytree': 0.17877578603550917, 'min_child_samples': 63, 'min_child_weight': 0.013980976720323135, 'reg_alpha': 4.342209418520701e-08, 'reg_lambda': 0.29190850453588846, 'num_leaves': 133}. Best is trial 0 with value: 0.8410105247285571.
# [I 2024-11-27 17:56:41,828] Trial 1 finished with value: 0.8589831924765626 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 3, 'learning_rate': 0.09331362328603034, 'subsample': 0.43350573067531595, 'subsample_freq': 4, 'colsample_bytree': 0.3996892930721282, 'min_child_samples': 94, 'min_child_weight': 0.1351160042015722, 'reg_alpha': 1.526104091764039e-08, 'reg_lambda': 1.5756112230950497e-09, 'num_leaves': 8}. Best is trial 1 with value: 0.8589831924765626.
# [I 2024-11-27 17:56:41,988] Trial 2 finished with value: 0.825909094240876 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 1, 'learning_rate': 0.04089937896331011, 'subsample': 0.4310176297299574, 'subsample_freq': 7, 'colsample_bytree': 0.15297464430653057, 'min_child_samples': 72, 'min_child_weight': 0.002062811815577771, 'reg_alpha': 2.7429661194640276e-08, 'reg_lambda': 3.9107494332670985e-08, 'num_leaves': 224}. Best is trial 1 with value: 0.8589831924765626.
# [I 2024-11-27 17:56:42,166] Trial 3 finished with value: 0.7641957132490532 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 1, 'learning_rate': 0.0026819742163282367, 'subsample': 0.6014959957304663, 'subsample_freq': 1, 'colsample_bytree': 0.9288046755862385, 'min_child_samples': 36, 'min_child_weight': 0.011304457625860033, 'reg_alpha': 1.6075952875838452e-08, 'reg_lambda': 2.8566034141653724, 'num_leaves': 101}. Best is trial 1 with value: 0.8589831924765626.
# [I 2024-11-27 17:56:42,365] Trial 4 finished with value: 0.8630581085227159 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 5, 'learning_rate': 0.09904538091396632, 'subsample': 0.9767963516148719, 'subsample_freq': 9, 'colsample_bytree': 0.36309839180455206, 'min_child_samples': 93, 'min_child_weight': 2.0184155344415986, 'reg_alpha': 6.500466955055771e-05, 'reg_lambda': 0.546839699892756, 'num_leaves': 77}. Best is trial 4 with value: 0.8630581085227159.
# [I 2024-11-27 17:56:42,530] Trial 5 finished with value: 0.8491820324632012 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 3, 'learning_rate': 0.027206540116727063, 'subsample': 0.7898916556486894, 'subsample_freq': 7, 'colsample_bytree': 0.43873194619351896, 'min_child_samples': 32, 'min_child_weight': 14.06949738388596, 'reg_alpha': 0.004619181455052487, 'reg_lambda': 0.00045080966932913675, 'num_leaves': 90}. Best is trial 4 with value: 0.8630581085227159.
# [I 2024-11-27 17:56:42,725] Trial 6 finished with value: 0.8410848711346414 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 5, 'learning_rate': 0.43951412183099914, 'subsample': 0.5129210930456906, 'subsample_freq': 1, 'colsample_bytree': 0.8008212564721092, 'min_child_samples': 74, 'min_child_weight': 37.85431442414785, 'reg_alpha': 0.09261706194247546, 'reg_lambda': 0.0015629658129011857, 'num_leaves': 202}. Best is trial 4 with value: 0.8630581085227159.
# [I 2024-11-27 17:56:42,910] Trial 7 finished with value: 0.8623008223131367 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 3, 'learning_rate': 0.1425344133989565, 'subsample': 0.7758350575910199, 'subsample_freq': 8, 'colsample_bytree': 0.8103989395051222, 'min_child_samples': 86, 'min_child_weight': 0.5371346498271509, 'reg_alpha': 0.023779507465217595, 'reg_lambda': 0.0015007070669695824, 'num_leaves': 110}. Best is trial 4 with value: 0.8630581085227159.
# [I 2024-11-27 17:56:43,076] Trial 8 finished with value: 0.857642758188838 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 3, 'learning_rate': 0.08680994519824059, 'subsample': 0.19867926939603775, 'subsample_freq': 5, 'colsample_bytree': 0.4483387867294296, 'min_child_samples': 30, 'min_child_weight': 0.022350972489114603, 'reg_alpha': 0.06422829573984808, 'reg_lambda': 3.4050868477943655e-05, 'num_leaves': 85}. Best is trial 4 with value: 0.8630581085227159.
# [I 2024-11-27 17:56:43,281] Trial 9 finished with value: 0.8182471211710293 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 6, 'learning_rate': 0.004720751890706851, 'subsample': 0.663996385479918, 'subsample_freq': 6, 'colsample_bytree': 0.16926715047350022, 'min_child_samples': 38, 'min_child_weight': 11.700354159342128, 'reg_alpha': 0.0004267968192392602, 'reg_lambda': 0.31260188936398237, 'num_leaves': 244}. Best is trial 4 with value: 0.8630581085227159.
# [I 2024-11-27 17:56:43,456] Trial 10 finished with value: 0.8412741926870362 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.7852985464183739, 'subsample': 0.9676835542421444, 'subsample_freq': 10, 'colsample_bytree': 0.6049722711895953, 'min_child_samples': 98, 'min_child_weight': 0.9681502553190464, 'reg_alpha': 1.2242363535266366e-05, 'reg_lambda': 4.37858921180749e-06, 'num_leaves': 11}. Best is trial 4 with value: 0.8630581085227159.
# [I 2024-11-27 17:56:43,638] Trial 11 finished with value: 0.8637142417347217 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.1858547160271633, 'subsample': 0.9918367023884915, 'subsample_freq': 10, 'colsample_bytree': 0.6871932745592366, 'min_child_samples': 85, 'min_child_weight': 1.1910220633965907, 'reg_alpha': 2.036291626076965, 'reg_lambda': 0.025344118671071735, 'num_leaves': 155}. Best is trial 11 with value: 0.8637142417347217.
# [I 2024-11-27 17:56:43,819] Trial 12 finished with value: 0.8482651632636606 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.011751950681341406, 'subsample': 0.9956587638955577, 'subsample_freq': 10, 'colsample_bytree': 0.6163412449827639, 'min_child_samples': 6, 'min_child_weight': 2.968352307490732, 'reg_alpha': 8.389618609977822e-06, 'reg_lambda': 0.03174704650213462, 'num_leaves': 165}. Best is trial 11 with value: 0.8637142417347217.
# [I 2024-11-27 17:56:44,008] Trial 13 finished with value: 0.8643561339449983 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.27829729071817255, 'subsample': 0.908153645795532, 'subsample_freq': 9, 'colsample_bytree': 0.3453615393939399, 'min_child_samples': 82, 'min_child_weight': 0.1419482248224551, 'reg_alpha': 2.3735359095183703, 'reg_lambda': 0.024688980426029124, 'num_leaves': 50}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:44,187] Trial 14 finished with value: 0.861171804073136 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.2874233862518936, 'subsample': 0.8743371656813758, 'subsample_freq': 9, 'colsample_bytree': 0.6851166169512862, 'min_child_samples': 55, 'min_child_weight': 0.13146637357525598, 'reg_alpha': 7.879680906510623, 'reg_lambda': 0.011199056028102911, 'num_leaves': 52}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:44,354] Trial 15 finished with value: 0.8568406547091119 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 2, 'learning_rate': 0.2736924797708726, 'subsample': 0.6924267921433007, 'subsample_freq': 3, 'colsample_bytree': 0.31918721806664124, 'min_child_samples': 81, 'min_child_weight': 0.0964600920204057, 'reg_alpha': 8.471942646697363, 'reg_lambda': 1.4182481631572788e-05, 'num_leaves': 160}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:44,548] Trial 16 finished with value: 0.8334753594020455 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.9402084634187935, 'subsample': 0.8715380440466194, 'subsample_freq': 8, 'colsample_bytree': 0.5275998051757147, 'min_child_samples': 65, 'min_child_weight': 4.990087708835169, 'reg_alpha': 1.0307466588807104, 'reg_lambda': 0.014596711070248574, 'num_leaves': 49}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:44,699] Trial 17 finished with value: 0.8417592244518 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 2, 'learning_rate': 0.024070282583546147, 'subsample': 0.18237634450560025, 'subsample_freq': 10, 'colsample_bytree': 0.7384289287003345, 'min_child_samples': 78, 'min_child_weight': 0.346270738597137, 'reg_alpha': 0.6989836824086485, 'reg_lambda': 6.637998244410194, 'num_leaves': 152}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:44,896] Trial 18 finished with value: 0.8612553652450446 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.1896930151618376, 'subsample': 0.766898829181154, 'subsample_freq': 8, 'colsample_bytree': 0.2629720598996886, 'min_child_samples': 50, 'min_child_weight': 0.0010021153792009645, 'reg_alpha': 0.0013306827414248995, 'reg_lambda': 7.738816455450922e-07, 'num_leaves': 183}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:45,075] Trial 19 finished with value: 0.8557487049589052 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.5003028739667109, 'subsample': 0.8928181544355192, 'subsample_freq': 6, 'colsample_bytree': 0.9972941956356531, 'min_child_samples': 87, 'min_child_weight': 0.04902627695680523, 'reg_alpha': 8.331744936584027e-07, 'reg_lambda': 0.00018409232947210133, 'num_leaves': 130}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:45,243] Trial 20 finished with value: 0.8373631528740123 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 2, 'learning_rate': 0.01069163033948005, 'subsample': 0.30272610907154673, 'subsample_freq': 3, 'colsample_bytree': 0.5176882892785618, 'min_child_samples': 100, 'min_child_weight': 72.57147183803889, 'reg_alpha': 0.7023265593524319, 'reg_lambda': 0.06002687160819361, 'num_leaves': 42}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:45,446] Trial 21 finished with value: 0.8384647362430352 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.0010860326889704872, 'subsample': 0.993704886660485, 'subsample_freq': 9, 'colsample_bytree': 0.3162433428385543, 'min_child_samples': 89, 'min_child_weight': 1.204108031237213, 'reg_alpha': 0.00011885918375697754, 'reg_lambda': 0.573337300900437, 'num_leaves': 68}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:45,638] Trial 22 finished with value: 0.8617981987227078 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.16730906570337317, 'subsample': 0.9290069778313218, 'subsample_freq': 9, 'colsample_bytree': 0.34781794161833607, 'min_child_samples': 67, 'min_child_weight': 4.1211857293754415, 'reg_alpha': 9.252928328937158e-06, 'reg_lambda': 0.006670951169690159, 'num_leaves': 29}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:45,860] Trial 23 finished with value: 0.8571767842352112 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 6, 'learning_rate': 0.07011608066332475, 'subsample': 0.8370945963913858, 'subsample_freq': 10, 'colsample_bytree': 0.24717884850943833, 'min_child_samples': 91, 'min_child_weight': 1.3826025757921843, 'reg_alpha': 0.006857065249314818, 'reg_lambda': 0.10977499764429136, 'num_leaves': 70}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:46,054] Trial 24 finished with value: 0.8593334582911426 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.36205248648904265, 'subsample': 0.7254785723866981, 'subsample_freq': 9, 'colsample_bytree': 0.48881609588691644, 'min_child_samples': 83, 'min_child_weight': 0.31288983485406735, 'reg_alpha': 1.191105302448689e-09, 'reg_lambda': 1.2843583331585564, 'num_leaves': 114}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:46,238] Trial 25 finished with value: 0.8628296242155669 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.14216612601085776, 'subsample': 0.9192340734731771, 'subsample_freq': 7, 'colsample_bytree': 0.6576282045688225, 'min_child_samples': 55, 'min_child_weight': 10.565601810960565, 'reg_alpha': 9.04132039473684e-05, 'reg_lambda': 0.002500390039204567, 'num_leaves': 74}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:46,435] Trial 26 finished with value: 0.8367780152441546 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.03883441946539355, 'subsample': 0.9410808849163484, 'subsample_freq': 8, 'colsample_bytree': 0.1067044571266475, 'min_child_samples': 76, 'min_child_weight': 2.208448630585864, 'reg_alpha': 5.459490899245406e-07, 'reg_lambda': 4.640725575858155, 'num_leaves': 142}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:46,660] Trial 27 finished with value: 0.8526726485854811 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 6, 'learning_rate': 0.5557194244207303, 'subsample': 0.9957018277686328, 'subsample_freq': 9, 'colsample_bytree': 0.4059209503205589, 'min_child_samples': 93, 'min_child_weight': 0.5319410845147144, 'reg_alpha': 0.18318652140280883, 'reg_lambda': 0.11554455647714772, 'num_leaves': 31}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:46,873] Trial 28 finished with value: 0.8545830370821025 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 5, 'learning_rate': 0.22410004587828117, 'subsample': 0.6298899327717448, 'subsample_freq': 6, 'colsample_bytree': 0.26169366227203417, 'min_child_samples': 13, 'min_child_weight': 0.22309418428345956, 'reg_alpha': 0.009044733886173172, 'reg_lambda': 0.0002488849423383305, 'num_leaves': 187}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:47,095] Trial 29 finished with value: 0.8613184026203443 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 6, 'learning_rate': 0.11561001891604844, 'subsample': 0.815458567016546, 'subsample_freq': 0, 'colsample_bytree': 0.5777737362851201, 'min_child_samples': 69, 'min_child_weight': 0.014264917984750252, 'reg_alpha': 1.7362170094083018, 'reg_lambda': 0.45494998145198223, 'num_leaves': 122}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:47,272] Trial 30 finished with value: 0.8586680056000645 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.04531924111428851, 'subsample': 0.8418157402486632, 'subsample_freq': 10, 'colsample_bytree': 0.7445178714669298, 'min_child_samples': 48, 'min_child_weight': 0.05975668921066183, 'reg_alpha': 0.0009612611706032864, 'reg_lambda': 9.821472329091549, 'num_leaves': 92}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:47,473] Trial 31 finished with value: 0.8618947443373693 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.059296261481061166, 'subsample': 0.9175621206191009, 'subsample_freq': 7, 'colsample_bytree': 0.6450600200033089, 'min_child_samples': 58, 'min_child_weight': 9.900868554887277, 'reg_alpha': 7.076530249397627e-05, 'reg_lambda': 0.002649988162594196, 'num_leaves': 59}. Best is trial 13 with value: 0.8643561339449983.
# [I 2024-11-27 17:56:47,665] Trial 32 finished with value: 0.8651969813264866 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.10571507830065287, 'subsample': 0.9251431543814541, 'subsample_freq': 8, 'colsample_bytree': 0.6787171445927545, 'min_child_samples': 43, 'min_child_weight': 5.625249967481208, 'reg_alpha': 1.2708070859455648e-06, 'reg_lambda': 0.03268611919666046, 'num_leaves': 78}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:47,827] Trial 33 finished with value: 0.8553413704241619 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.09160197545916111, 'subsample': 0.10057793317764985, 'subsample_freq': 8, 'colsample_bytree': 0.7242145104892993, 'min_child_samples': 43, 'min_child_weight': 0.735529751966603, 'reg_alpha': 2.3939289510447166e-07, 'reg_lambda': 0.0395014349256197, 'num_leaves': 23}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:48,002] Trial 34 finished with value: 0.8626805125504063 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.23958464945690114, 'subsample': 0.732126363851927, 'subsample_freq': 9, 'colsample_bytree': 0.82824299315866, 'min_child_samples': 61, 'min_child_weight': 4.870220263628974, 'reg_alpha': 1.240138659656131e-07, 'reg_lambda': 4.4404798999135525e-09, 'num_leaves': 81}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:48,174] Trial 35 finished with value: 0.8457172805131787 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 5, 'learning_rate': 0.019976945742672787, 'subsample': 0.5509985473804062, 'subsample_freq': 10, 'colsample_bytree': 0.3744486873516568, 'min_child_samples': 82, 'min_child_weight': 25.24860779092791, 'reg_alpha': 2.424183806325328e-06, 'reg_lambda': 1.5495164085928976, 'num_leaves': 6}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:48,395] Trial 36 finished with value: 0.8582381577169998 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 6, 'learning_rate': 0.05798644147423368, 'subsample': 0.4028850918373498, 'subsample_freq': 7, 'colsample_bytree': 0.8550263010784727, 'min_child_samples': 96, 'min_child_weight': 1.9787236464507105, 'reg_alpha': 3.33353706928892e-05, 'reg_lambda': 0.16344716634674883, 'num_leaves': 98}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:48,604] Trial 37 finished with value: 0.8643567622244863 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.11656339722334338, 'subsample': 0.9407951273876076, 'subsample_freq': 8, 'colsample_bytree': 0.4660138669612978, 'min_child_samples': 21, 'min_child_weight': 0.2331691985021846, 'reg_alpha': 5.326067878530408e-09, 'reg_lambda': 0.009814455463371133, 'num_leaves': 109}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:48,795] Trial 38 finished with value: 0.8609196545719373 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.6196795459978333, 'subsample': 0.8671611732265401, 'subsample_freq': 5, 'colsample_bytree': 0.4710366061258637, 'min_child_samples': 21, 'min_child_weight': 0.0050617724733605365, 'reg_alpha': 1.5816247277644689e-09, 'reg_lambda': 0.0007350456811367346, 'num_leaves': 108}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:48,980] Trial 39 finished with value: 0.8582412991144401 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.35248937956557036, 'subsample': 0.8070369236285417, 'subsample_freq': 8, 'colsample_bytree': 0.5725714971426705, 'min_child_samples': 20, 'min_child_weight': 0.03956356263923937, 'reg_alpha': 1.1735661601368275e-07, 'reg_lambda': 0.006591192612868291, 'num_leaves': 140}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:49,154] Trial 40 finished with value: 0.8613885604965084 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.11308538282985339, 'subsample': 0.9537758888484944, 'subsample_freq': 4, 'colsample_bytree': 0.8836477134231215, 'min_child_samples': 27, 'min_child_weight': 0.38681710072632036, 'reg_alpha': 2.251866674221302e-08, 'reg_lambda': 0.030139333311419103, 'num_leaves': 121}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:49,358] Trial 41 finished with value: 0.8651100693306416 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.13949897332857886, 'subsample': 0.9064097738125476, 'subsample_freq': 9, 'colsample_bytree': 0.4296743430272048, 'min_child_samples': 39, 'min_child_weight': 0.22320154032661355, 'reg_alpha': 0.2125355595401004, 'reg_lambda': 0.8385307169225976, 'num_leaves': 65}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:49,545] Trial 42 finished with value: 0.8636654453611509 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.14776412404915024, 'subsample': 0.9047006754634461, 'subsample_freq': 9, 'colsample_bytree': 0.4201560154668633, 'min_child_samples': 40, 'min_child_weight': 0.18512217097453929, 'reg_alpha': 4.45279979428025e-09, 'reg_lambda': 0.6165345377562961, 'num_leaves': 61}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:49,740] Trial 43 finished with value: 0.8594974392375201 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 3, 'learning_rate': 0.07778860778724557, 'subsample': 0.9463108930982538, 'subsample_freq': 8, 'colsample_bytree': 0.7715179627915979, 'min_child_samples': 45, 'min_child_weight': 0.0894783978148701, 'reg_alpha': 2.7607373574377037, 'reg_lambda': 0.005368187608301464, 'num_leaves': 41}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:49,933] Trial 44 finished with value: 0.8589079036512463 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.3771034752340774, 'subsample': 0.7636439812350957, 'subsample_freq': 10, 'colsample_bytree': 0.5052027478733099, 'min_child_samples': 34, 'min_child_weight': 0.028470058899255198, 'reg_alpha': 0.019816399004523345, 'reg_lambda': 0.01682399804317764, 'num_leaves': 103}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:50,140] Trial 45 finished with value: 0.8609523251053153 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.19839285125221817, 'subsample': 0.8669679337489332, 'subsample_freq': 7, 'colsample_bytree': 0.6906698802691045, 'min_child_samples': 22, 'min_child_weight': 0.18610091942842377, 'reg_alpha': 0.24596413742146223, 'reg_lambda': 0.0008281269176548355, 'num_leaves': 221}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:50,336] Trial 46 finished with value: 0.8610710699285542 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.11391156431620768, 'subsample': 0.9573082193132786, 'subsample_freq': 9, 'colsample_bytree': 0.5521894384301618, 'min_child_samples': 10, 'min_child_weight': 0.759978336928444, 'reg_alpha': 8.579924872548172e-09, 'reg_lambda': 0.16645814946232174, 'num_leaves': 86}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:50,549] Trial 47 finished with value: 0.8644340406015149 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.2886216954809963, 'subsample': 0.8222575912690021, 'subsample_freq': 10, 'colsample_bytree': 0.446030234296151, 'min_child_samples': 27, 'min_child_weight': 0.09875028408797037, 'reg_alpha': 3.2917983454541124, 'reg_lambda': 2.5390113789275666, 'num_leaves': 170}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:50,758] Trial 48 finished with value: 0.832662994024015 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 5, 'learning_rate': 0.698995608153256, 'subsample': 0.8056095986354023, 'subsample_freq': 8, 'colsample_bytree': 0.44921940249777337, 'min_child_samples': 28, 'min_child_weight': 0.08741109014785108, 'reg_alpha': 0.033465493021123255, 'reg_lambda': 1.4288344573997969, 'num_leaves': 172}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:50,938] Trial 49 finished with value: 0.8328435196635773 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 1, 'learning_rate': 0.046299329295812125, 'subsample': 0.6846023029255582, 'subsample_freq': 6, 'colsample_bytree': 0.21885926471937142, 'min_child_samples': 36, 'min_child_weight': 0.007413789901325171, 'reg_alpha': 0.35482998571620344, 'reg_lambda': 4.958143653247321e-05, 'num_leaves': 198}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:51,127] Trial 50 finished with value: 0.8622991469011686 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 3, 'learning_rate': 0.31109758172041496, 'subsample': 0.8946806708170264, 'subsample_freq': 7, 'colsample_bytree': 0.3312672464387502, 'min_child_samples': 24, 'min_child_weight': 0.020609184255872496, 'reg_alpha': 3.1549057193499097, 'reg_lambda': 3.074769587734308, 'num_leaves': 58}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:51,327] Trial 51 finished with value: 0.8620689871820514 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.24901310168122034, 'subsample': 0.8393527086298467, 'subsample_freq': 10, 'colsample_bytree': 0.386223310472047, 'min_child_samples': 15, 'min_child_weight': 0.13427985218881672, 'reg_alpha': 5.568937259540714, 'reg_lambda': 0.05859918627702028, 'num_leaves': 151}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:51,531] Trial 52 finished with value: 0.8597629920344632 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.145056493631138, 'subsample': 0.9793689861742856, 'subsample_freq': 9, 'colsample_bytree': 0.29559770739660596, 'min_child_samples': 32, 'min_child_weight': 0.27404074093116304, 'reg_alpha': 0.12587750922784113, 'reg_lambda': 0.2131706315067268, 'num_leaves': 173}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:51,729] Trial 53 finished with value: 0.8576379413794295 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.43414080636937774, 'subsample': 0.9032573018360972, 'subsample_freq': 10, 'colsample_bytree': 0.45391147634945006, 'min_child_samples': 40, 'min_child_weight': 0.155457518128759, 'reg_alpha': 1.0401520344119757, 'reg_lambda': 1.0374725085566951, 'num_leaves': 136}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:51,927] Trial 54 finished with value: 0.8610637400011937 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.1877182136450008, 'subsample': 0.9623839612867424, 'subsample_freq': 9, 'colsample_bytree': 0.6161470020862492, 'min_child_samples': 45, 'min_child_weight': 0.4984209461708545, 'reg_alpha': 8.199939393866519, 'reg_lambda': 0.018427585790130978, 'num_leaves': 148}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:52,140] Trial 55 finished with value: 0.8631025069398703 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 5, 'learning_rate': 0.08789862229123639, 'subsample': 0.9994673337384642, 'subsample_freq': 10, 'colsample_bytree': 0.39627210436113, 'min_child_samples': 71, 'min_child_weight': 0.08615941206535346, 'reg_alpha': 0.4751164347945146, 'reg_lambda': 0.07902008950002538, 'num_leaves': 162}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:52,353] Trial 56 finished with value: 0.8559771892660544 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.29958025502998614, 'subsample': 0.8847845090729948, 'subsample_freq': 8, 'colsample_bytree': 0.5167655226357685, 'min_child_samples': 17, 'min_child_weight': 1.3387684343214055, 'reg_alpha': 0.06377377648227699, 'reg_lambda': 2.5218769479515634e-06, 'num_leaves': 94}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:52,549] Trial 57 finished with value: 0.8542092107867211 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.8391077858335306, 'subsample': 0.9299203881636446, 'subsample_freq': 10, 'colsample_bytree': 0.4833003712320561, 'min_child_samples': 30, 'min_child_weight': 20.439068167059354, 'reg_alpha': 2.5372086976711827, 'reg_lambda': 2.9970095174174576, 'num_leaves': 46}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:52,741] Trial 58 finished with value: 0.86403780567106 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.11988998924120772, 'subsample': 0.759304167970784, 'subsample_freq': 9, 'colsample_bytree': 0.4283081213677731, 'min_child_samples': 52, 'min_child_weight': 0.05460195714881972, 'reg_alpha': 0.0002749346546735127, 'reg_lambda': 0.31567819846184964, 'num_leaves': 215}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:52,939] Trial 59 finished with value: 0.8646260846983578 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.1280172524768562, 'subsample': 0.7565147207843351, 'subsample_freq': 8, 'colsample_bytree': 0.4302001421636403, 'min_child_samples': 51, 'min_child_weight': 0.0550826420492207, 'reg_alpha': 2.8698505768998485e-06, 'reg_lambda': 0.23979391631106456, 'num_leaves': 232}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:53,137] Trial 60 finished with value: 0.8603305378386558 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.06509304231271404, 'subsample': 0.5594514617137147, 'subsample_freq': 7, 'colsample_bytree': 0.3412621826839074, 'min_child_samples': 48, 'min_child_weight': 0.025718147150759155, 'reg_alpha': 1.4836305768895957e-06, 'reg_lambda': 0.9280600439220449, 'num_leaves': 206}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:53,356] Trial 61 finished with value: 0.8638564423255136 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.12225430358507576, 'subsample': 0.7348519988889919, 'subsample_freq': 8, 'colsample_bytree': 0.423495322732389, 'min_child_samples': 51, 'min_child_weight': 0.05883573788245568, 'reg_alpha': 4.929781924284524e-06, 'reg_lambda': 0.3233896941842724, 'num_leaves': 256}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:53,573] Trial 62 finished with value: 0.8557161391387754 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.03288105508948128, 'subsample': 0.7719003097100544, 'subsample_freq': 9, 'colsample_bytree': 0.36380533205340365, 'min_child_samples': 54, 'min_child_weight': 0.041700115880802975, 'reg_alpha': 2.8263881876972208e-05, 'reg_lambda': 0.4357684706127209, 'num_leaves': 226}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:53,775] Trial 63 finished with value: 0.8605347286722674 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 5, 'learning_rate': 0.09906837418991832, 'subsample': 0.4718414747648099, 'subsample_freq': 8, 'colsample_bytree': 0.5411946059972575, 'min_child_samples': 61, 'min_child_weight': 0.11862297798958371, 'reg_alpha': 7.00043345852988e-08, 'reg_lambda': 1.9582940472570417e-07, 'num_leaves': 236}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:53,981] Trial 64 finished with value: 0.863511516886582 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.16566928995162536, 'subsample': 0.8297130870557973, 'subsample_freq': 9, 'colsample_bytree': 0.4254422786240275, 'min_child_samples': 38, 'min_child_weight': 0.2586941534266578, 'reg_alpha': 0.0003260547597962246, 'reg_lambda': 4.465691010908654, 'num_leaves': 207}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:54,177] Trial 65 finished with value: 0.8600756657930091 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.2203674762901725, 'subsample': 0.5968522957802551, 'subsample_freq': 2, 'colsample_bytree': 0.3050978724849314, 'min_child_samples': 56, 'min_child_weight': 0.015133767169062964, 'reg_alpha': 2.77724721856231e-07, 'reg_lambda': 0.067317069079608, 'num_leaves': 250}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:54,358] Trial 66 finished with value: 0.8612564123775247 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.14014369633173487, 'subsample': 0.7868313914913552, 'subsample_freq': 9, 'colsample_bytree': 0.4639112441507483, 'min_child_samples': 41, 'min_child_weight': 0.07485738804152163, 'reg_alpha': 0.0028818162536286824, 'reg_lambda': 0.20405936620465148, 'num_leaves': 237}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:54,545] Trial 67 finished with value: 0.8582438122323923 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 2, 'learning_rate': 0.44030975116917664, 'subsample': 0.851151240301271, 'subsample_freq': 8, 'colsample_bytree': 0.4913505502594705, 'min_child_samples': 47, 'min_child_weight': 0.037628270601723766, 'reg_alpha': 0.00023329152535195603, 'reg_lambda': 1.849071377363005, 'num_leaves': 215}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:54,749] Trial 68 finished with value: 0.8599548267048102 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.05387026663112057, 'subsample': 0.6485879929533537, 'subsample_freq': 9, 'colsample_bytree': 0.3832070907861766, 'min_child_samples': 51, 'min_child_weight': 0.12054376530732806, 'reg_alpha': 3.7720133721454405e-06, 'reg_lambda': 9.935636660056792, 'num_leaves': 68}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:54,954] Trial 69 finished with value: 0.8361418822625182 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.015592776804575747, 'subsample': 0.7170173714089007, 'subsample_freq': 8, 'colsample_bytree': 0.28489989202219185, 'min_child_samples': 26, 'min_child_weight': 0.38707383550951424, 'reg_alpha': 1.7896337258107454e-05, 'reg_lambda': 0.01057213702924199, 'num_leaves': 77}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:55,168] Trial 70 finished with value: 0.8425186049263393 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.0021956526058318298, 'subsample': 0.8107733776827581, 'subsample_freq': 6, 'colsample_bytree': 0.5760236128057714, 'min_child_samples': 35, 'min_child_weight': 79.61777695499998, 'reg_alpha': 0.0007932472242898275, 'reg_lambda': 0.003194122146698721, 'num_leaves': 229}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:55,363] Trial 71 finished with value: 0.8622796702370394 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.11698026591494767, 'subsample': 0.7544124253530096, 'subsample_freq': 7, 'colsample_bytree': 0.4419932006402657, 'min_child_samples': 52, 'min_child_weight': 0.059529804182892374, 'reg_alpha': 1.0121533802745392e-05, 'reg_lambda': 0.32300705903231836, 'num_leaves': 247}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:55,580] Trial 72 finished with value: 0.8626719260640698 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.08050971789043507, 'subsample': 0.7406548613836907, 'subsample_freq': 8, 'colsample_bytree': 0.4212733634908579, 'min_child_samples': 58, 'min_child_weight': 0.05852223391002514, 'reg_alpha': 5.645675890629875e-06, 'reg_lambda': 0.6255898324788144, 'num_leaves': 253}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:55,787] Trial 73 finished with value: 0.8618482516552548 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.12794930891279593, 'subsample': 0.7114487344201462, 'subsample_freq': 9, 'colsample_bytree': 0.4095758453168241, 'min_child_samples': 45, 'min_child_weight': 0.19116827592871366, 'reg_alpha': 8.629283482504285e-07, 'reg_lambda': 0.041652955650838625, 'num_leaves': 238}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:55,997] Trial 74 finished with value: 0.8626872141982788 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 5, 'learning_rate': 0.17546243557510557, 'subsample': 0.6737631124147734, 'subsample_freq': 8, 'colsample_bytree': 0.3402031133106199, 'min_child_samples': 64, 'min_child_weight': 0.00930249051095121, 'reg_alpha': 2.0065093572322905e-06, 'reg_lambda': 0.09941962845540403, 'num_leaves': 193}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:56,204] Trial 75 finished with value: 0.863581884189242 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.24605927382136655, 'subsample': 0.8689307555383197, 'subsample_freq': 9, 'colsample_bytree': 0.36525457377706766, 'min_child_samples': 42, 'min_child_weight': 0.03183317525470196, 'reg_alpha': 7.843940940291899e-07, 'reg_lambda': 0.3596961195183303, 'num_leaves': 37}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:56,394] Trial 76 finished with value: 0.8609076125484167 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.10219311078570194, 'subsample': 0.7884972711595561, 'subsample_freq': 5, 'colsample_bytree': 0.4947795947596831, 'min_child_samples': 49, 'min_child_weight': 0.07120284518978565, 'reg_alpha': 4.7665887561326886e-08, 'reg_lambda': 0.02419852085018675, 'num_leaves': 217}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:56,604] Trial 77 finished with value: 0.8626807219769023 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.07307109870304819, 'subsample': 0.9274246604961197, 'subsample_freq': 10, 'colsample_bytree': 0.4394120560986568, 'min_child_samples': 53, 'min_child_weight': 0.019755562147978748, 'reg_alpha': 2.9343825260369814e-07, 'reg_lambda': 2.4380772316379717, 'num_leaves': 242}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:56,808] Trial 78 finished with value: 0.8619479386673563 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.2954975713017898, 'subsample': 0.8240350190954552, 'subsample_freq': 8, 'colsample_bytree': 0.5336214642402639, 'min_child_samples': 32, 'min_child_weight': 0.8321320339085267, 'reg_alpha': 1.3840375889797503, 'reg_lambda': 0.8866178235401357, 'num_leaves': 53}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:57,003] Trial 79 finished with value: 0.861365733008443 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.21735225196990643, 'subsample': 0.8530749151334993, 'subsample_freq': 9, 'colsample_bytree': 0.4674759593805238, 'min_child_samples': 58, 'min_child_weight': 0.12241031731545998, 'reg_alpha': 0.000163436162756451, 'reg_lambda': 0.12403858961629437, 'num_leaves': 256}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:57,172] Trial 80 finished with value: 0.861401126086269 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.17750869843596354, 'subsample': 0.6138628365760255, 'subsample_freq': 10, 'colsample_bytree': 0.39967761266423657, 'min_child_samples': 18, 'min_child_weight': 0.04940237124676919, 'reg_alpha': 3.708900021967582e-05, 'reg_lambda': 0.26746854861315245, 'num_leaves': 18}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:57,358] Trial 81 finished with value: 0.863494762766901 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.1573825204157689, 'subsample': 0.9739356110239143, 'subsample_freq': 10, 'colsample_bytree': 0.6987783310283734, 'min_child_samples': 84, 'min_child_weight': 6.032428653180589, 'reg_alpha': 3.0548860722175446, 'reg_lambda': 0.030893587901179142, 'num_leaves': 127}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:57,538] Trial 82 finished with value: 0.8620608195487068 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.12714764034912754, 'subsample': 0.9096097449195825, 'subsample_freq': 10, 'colsample_bytree': 0.7782187699615366, 'min_child_samples': 78, 'min_child_weight': 2.9214526622324537, 'reg_alpha': 0.6705288263573451, 'reg_lambda': 0.009681419848866057, 'num_leaves': 185}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:57,726] Trial 83 finished with value: 0.8580128148072907 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.3555050526280085, 'subsample': 0.9373835015621542, 'subsample_freq': 9, 'colsample_bytree': 0.6458334992438235, 'min_child_samples': 12, 'min_child_weight': 0.5959988379623552, 'reg_alpha': 8.948108602369573e-09, 'reg_lambda': 0.06268662418254807, 'num_leaves': 115}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:57,932] Trial 84 finished with value: 0.8615374627351728 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.09364257467904943, 'subsample': 0.8910761174905479, 'subsample_freq': 8, 'colsample_bytree': 0.42868990953283853, 'min_child_samples': 89, 'min_child_weight': 0.3618409069493937, 'reg_alpha': 5.386338893461849, 'reg_lambda': 0.0015223474643439156, 'num_leaves': 173}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:58,146] Trial 85 finished with value: 0.8548655534252226 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 6, 'learning_rate': 0.26765372996525366, 'subsample': 0.9620139161459583, 'subsample_freq': 9, 'colsample_bytree': 0.6690138380230057, 'min_child_samples': 46, 'min_child_weight': 0.22744765128376568, 'reg_alpha': 0.2128177726141116, 'reg_lambda': 0.0034935631463916105, 'num_leaves': 232}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:58,338] Trial 86 finished with value: 0.8633490019256767 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.20177634101527386, 'subsample': 0.6945245355153832, 'subsample_freq': 10, 'colsample_bytree': 0.5152567652834175, 'min_child_samples': 43, 'min_child_weight': 0.09668599375206977, 'reg_alpha': 4.193074929409226e-06, 'reg_lambda': 5.938286581674974, 'num_leaves': 84}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:58,539] Trial 87 finished with value: 0.8550854512460353 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 3, 'learning_rate': 0.5216684651122164, 'subsample': 0.7452142456770496, 'subsample_freq': 7, 'colsample_bytree': 0.604667470253672, 'min_child_samples': 74, 'min_child_weight': 0.1503193603795216, 'reg_alpha': 5.0058861009756335, 'reg_lambda': 0.13945929785400743, 'num_leaves': 156}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:58,712] Trial 88 finished with value: 0.8633173785247789 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.13516765896903954, 'subsample': 0.9801734729911336, 'subsample_freq': 9, 'colsample_bytree': 0.719657333440995, 'min_child_samples': 38, 'min_child_weight': 2.027266273547229, 'reg_alpha': 2.0305006479353863e-09, 'reg_lambda': 0.5876588031764347, 'num_leaves': 63}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:58,945] Trial 89 finished with value: 0.8492263261671076 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 5, 'learning_rate': 0.005802981423461091, 'subsample': 0.8815945300752872, 'subsample_freq': 8, 'colsample_bytree': 0.4729133248236902, 'min_child_samples': 67, 'min_child_weight': 8.440346912400186, 'reg_alpha': 0.06160243526408184, 'reg_lambda': 0.04374998676973821, 'num_leaves': 72}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:59,134] Trial 90 finished with value: 0.8550437753733289 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.10844399600976763, 'subsample': 0.9161355882949428, 'subsample_freq': 7, 'colsample_bytree': 0.22018840220545047, 'min_child_samples': 56, 'min_child_weight': 1.0153864301113913, 'reg_alpha': 1.416742774838102, 'reg_lambda': 0.015009390196004653, 'num_leaves': 144}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:59,323] Trial 91 finished with value: 0.8630359093141388 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.15699184679594405, 'subsample': 0.9460839884316519, 'subsample_freq': 9, 'colsample_bytree': 0.4091883099751298, 'min_child_samples': 24, 'min_child_weight': 0.16771902893275917, 'reg_alpha': 3.048428003725034e-09, 'reg_lambda': 0.634689430684917, 'num_leaves': 53}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:59,514] Trial 92 finished with value: 0.8603900149635233 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.07995594946936976, 'subsample': 0.9061826044943015, 'subsample_freq': 10, 'colsample_bytree': 0.35891499182057557, 'min_child_samples': 39, 'min_child_weight': 0.21721230194204558, 'reg_alpha': 2.826207525729095e-09, 'reg_lambda': 1.6202970490668427, 'num_leaves': 58}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:59,693] Trial 93 finished with value: 0.860126765858036 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.06635475623538103, 'subsample': 0.3709438083408915, 'subsample_freq': 9, 'colsample_bytree': 0.5540855534770508, 'min_child_samples': 29, 'min_child_weight': 0.432077340027258, 'reg_alpha': 1.482921220163874e-08, 'reg_lambda': 0.22009088896782378, 'num_leaves': 34}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:56:59,881] Trial 94 finished with value: 0.8580126053807949 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.05236854355376811, 'subsample': 0.859563948383493, 'subsample_freq': 8, 'colsample_bytree': 0.38822986876442106, 'min_child_samples': 50, 'min_child_weight': 45.53210174316424, 'reg_alpha': 0.7190270259575047, 'reg_lambda': 0.9706039648114099, 'num_leaves': 105}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:57:00,087] Trial 95 finished with value: 0.864419171320298 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.19854348388651552, 'subsample': 0.9989005561180866, 'subsample_freq': 10, 'colsample_bytree': 0.447983418106897, 'min_child_samples': 95, 'min_child_weight': 0.2949246502427769, 'reg_alpha': 3.9824149442216434e-09, 'reg_lambda': 0.005316625925081444, 'num_leaves': 64}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:57:00,283] Trial 96 finished with value: 0.8600172358006217 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.31818491286985434, 'subsample': 0.9741342536148053, 'subsample_freq': 10, 'colsample_bytree': 0.32202478039570587, 'min_child_samples': 97, 'min_child_weight': 0.26721984871364746, 'reg_alpha': 0.0032901183196482283, 'reg_lambda': 0.006356802707099166, 'num_leaves': 65}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:57:00,482] Trial 97 finished with value: 0.8538735001136138 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.44083077813472715, 'subsample': 0.9901939144841921, 'subsample_freq': 10, 'colsample_bytree': 0.4381288132867799, 'min_child_samples': 94, 'min_child_weight': 0.59979630645385, 'reg_alpha': 0.0127069123099537, 'reg_lambda': 0.00048325750866800985, 'num_leaves': 98}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:57:00,700] Trial 98 finished with value: 0.8616134845532253 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.19973843989339418, 'subsample': 0.7942536698628067, 'subsample_freq': 10, 'colsample_bytree': 0.48139054332999803, 'min_child_samples': 91, 'min_child_weight': 0.10724831971414515, 'reg_alpha': 1.2649335668249316e-07, 'reg_lambda': 0.01701575449388179, 'num_leaves': 179}. Best is trial 32 with value: 0.8651969813264866.
# [I 2024-11-27 17:57:00,905] Trial 99 finished with value: 0.8613944244383966 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 5, 'learning_rate': 0.27028054583406086, 'subsample': 0.9383391389272997, 'subsample_freq': 0, 'colsample_bytree': 0.4584893128659355, 'min_child_samples': 99, 'min_child_weight': 0.07097373683822072, 'reg_alpha': 6.47346468023103e-09, 'reg_lambda': 0.0042971348553475, 'num_leaves': 48}. Best is trial 32 with value: 0.8651969813264866.

# %%
print("Number of finished trials: {}".format(len(study_h1n1.trials)))
print("Best trial:")
trial = study_h1n1.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Number of finished trials: 100
# Best trial:
#   Value: 0.8651969813264866
#   Params:
#     encoders: OrdinalEncoder
#     max_depth: 5
#     learning_rate: 0.10571507830065287
#     subsample: 0.9251431543814541
#     subsample_freq: 8
#     colsample_bytree: 0.6787171445927545
#     min_child_samples: 43
#     min_child_weight: 5.625249967481208
#     reg_alpha: 1.2708070859455648e-06
#     reg_lambda: 0.03268611919666046
#     num_leaves: 78

# %% [markdown]
# **werte mit Pruning**
#
# Number of finished trials: 100
#
# Best trial:
#
#   Value: 0.8656566724852328
#
#   Params:
#
#     encoders: TargetEncoder
#     max_depth: 6
#     learning_rate: 0.10742032000145753
#     subsample: 0.8748896332353917
#     subsample_freq: 0
#     colsample_bytree: 0.4626980798205049
#     min_child_samples: 32
#     min_child_weight: 0.849752869542173
#     reg_alpha: 1.2148872803471023e-06
#     reg_lambda: 0.053174027171273695
#     num_leaves: 239

# %% [markdown]
# **Werte ohne Pruning**
#
# Number of finished trials: 100
#
# Best trial:
#
#   Value: 0.8656221171133909
#
#   Params:
#
#     encoders: OrdinalEncoder
#     max_depth: 4
#     learning_rate: 0.14637656019953735
#     subsample: 0.906919657644
#     subsample_freq: 4
#     colsample_bytree: 0.7873074510345616
#     min_child_samples: 27
#     min_child_weight: 0.0034631838050949815
#     reg_alpha: 2.6787233260886746e-06
#     reg_lambda: 0.005394939368622497
#     num_leaves: 40

# %%
def objective_seas(trial):
    
    dtrain = lgb.Dataset(X_train2, label=y_train2)
    dvalid = lgb.Dataset(X_test2, label=y_test2)

    '''First select the encoder'''
    encoders = trial.suggest_categorical("encoders", ["TargetEncoder", "OrdinalEncoder"])

    if encoders == "TargetEncoder":
        encoder = TargetEncoder()
    else:
        encoder = OrdinalEncoder()
    
    '''2nd select the model LGBM-model'''
    # instantiate parameters for classifier
    params = {
        'objective': 'binary', # i the previous 2 files I didn't explicitly define this, as LGBM would use this as default for the classifier
        'metric': 'auc',
        'verbosity': 0,
        'max_depth': trial.suggest_int('max_depth', 1, 6),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 1.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'subsample_freq': trial.suggest_int('subsample_freq', 0, 10),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        'min_child_weight': trial.suggest_float('min_child_weight', 0.001, 100, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-9, 10.0, log=True), # in LGBM; the value is not limited to [0 to 1] also knwon as lambda_l1
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-9, 10.0, log=True), # in LGBM ; the value is not limited to [0 to 1] also knwon as lambda_l2
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "random_state": 8,
        #"n_jobs": 1
    }

    classifier = lgb.LGBMClassifier(**params, callbacks=[optuna.integration.LightGBMPruningCallback(trial, "auc")])
    #classifier = lgb.LGBMClassifier(**params)

    pipe = Pipeline([('encoder', encoder), 
                     ('clf', classifier)])
    pipe.fit(X_train2, np.ravel(y_train2))

    y_pred = pipe.predict_proba(X_test2)[:, 1]
    score = roc_auc_score(y_test2, y_pred)

    return score

# %%
study_seas = optuna.create_study(direction="maximize", pruner=optuna.pruners.MedianPruner())
study_seas.optimize(objective_h1n1, n_trials=100)
# Out:
# [I 2024-11-27 17:46:43,644] A new study created in memory with name: no-name-2f637cc1-947a-4a35-81b3-14d5390aafe0
# [I 2024-11-27 17:46:43,792] Trial 0 finished with value: 0.817686381727957 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 1, 'learning_rate': 0.0012824868368541038, 'subsample': 0.877031346127817, 'subsample_freq': 1, 'colsample_bytree': 0.33129855580692746, 'min_child_samples': 27, 'min_child_weight': 0.013699437877886956, 'reg_alpha': 1.6812700848369745e-09, 'reg_lambda': 0.000111818537244868, 'num_leaves': 87}. Best is trial 0 with value: 0.817686381727957.
# [I 2024-11-27 17:46:43,956] Trial 1 finished with value: 0.8604461412644544 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.15022822346124712, 'subsample': 0.909992824557176, 'subsample_freq': 0, 'colsample_bytree': 0.27516160693060865, 'min_child_samples': 69, 'min_child_weight': 0.001129305800731012, 'reg_alpha': 2.6771299465578473e-05, 'reg_lambda': 4.283952807336383e-06, 'num_leaves': 197}. Best is trial 1 with value: 0.8604461412644544.
# [I 2024-11-27 17:46:44,123] Trial 2 finished with value: 0.8412044536638643 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.002383920953891044, 'subsample': 0.8021541503117591, 'subsample_freq': 5, 'colsample_bytree': 0.46136416300587435, 'min_child_samples': 78, 'min_child_weight': 12.663422749650387, 'reg_alpha': 0.07355715708232205, 'reg_lambda': 0.7866598333458477, 'num_leaves': 156}. Best is trial 1 with value: 0.8604461412644544.
# [I 2024-11-27 17:46:44,311] Trial 3 finished with value: 0.8473027438012375 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.002374346921835384, 'subsample': 0.90668735269653, 'subsample_freq': 5, 'colsample_bytree': 0.5368852065356614, 'min_child_samples': 74, 'min_child_weight': 0.02081430980198013, 'reg_alpha': 1.1193174177495231e-07, 'reg_lambda': 5.673145454709106e-08, 'num_leaves': 150}. Best is trial 1 with value: 0.8604461412644544.
# [I 2024-11-27 17:46:44,445] Trial 4 finished with value: 0.8442124464260845 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.0018760153948936603, 'subsample': 0.7874407276330717, 'subsample_freq': 0, 'colsample_bytree': 0.7333812766882625, 'min_child_samples': 98, 'min_child_weight': 0.017412915028472756, 'reg_alpha': 0.0007298321262004661, 'reg_lambda': 0.5555977780274985, 'num_leaves': 218}. Best is trial 1 with value: 0.8604461412644544.
# [I 2024-11-27 17:46:44,606] Trial 5 finished with value: 0.8564074560021112 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 2, 'learning_rate': 0.13570907493591375, 'subsample': 0.5433003995928831, 'subsample_freq': 1, 'colsample_bytree': 0.3163354536950902, 'min_child_samples': 96, 'min_child_weight': 4.137299177538352, 'reg_alpha': 3.79392171861361e-08, 'reg_lambda': 0.0010524065243863075, 'num_leaves': 181}. Best is trial 1 with value: 0.8604461412644544.
# [I 2024-11-27 17:46:44,769] Trial 6 finished with value: 0.8183035616117044 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.0025988886746460757, 'subsample': 0.4696469664090841, 'subsample_freq': 0, 'colsample_bytree': 0.23388247729381048, 'min_child_samples': 43, 'min_child_weight': 0.42974056595378995, 'reg_alpha': 0.02199068014542664, 'reg_lambda': 0.002410882045859185, 'num_leaves': 26}. Best is trial 1 with value: 0.8604461412644544.
# [I 2024-11-27 17:46:44,937] Trial 7 finished with value: 0.8267440776804761 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 2, 'learning_rate': 0.002027248216571359, 'subsample': 0.7300859015734916, 'subsample_freq': 2, 'colsample_bytree': 0.6023492966096218, 'min_child_samples': 92, 'min_child_weight': 16.161487460521464, 'reg_alpha': 5.402581352478733e-08, 'reg_lambda': 0.004886945769755717, 'num_leaves': 45}. Best is trial 1 with value: 0.8604461412644544.
# [I 2024-11-27 17:46:45,125] Trial 8 finished with value: 0.8477498693702231 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 6, 'learning_rate': 0.4018483426102366, 'subsample': 0.12856601673329454, 'subsample_freq': 0, 'colsample_bytree': 0.5808478856461144, 'min_child_samples': 39, 'min_child_weight': 0.09854188410950829, 'reg_alpha': 7.52076318002194e-05, 'reg_lambda': 1.23737426754833e-09, 'num_leaves': 76}. Best is trial 1 with value: 0.8604461412644544.
# [I 2024-11-27 17:46:45,307] Trial 9 finished with value: 0.8393902966421602 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.013228933012393636, 'subsample': 0.24865101002502354, 'subsample_freq': 2, 'colsample_bytree': 0.9778878916209851, 'min_child_samples': 29, 'min_child_weight': 92.02183945524398, 'reg_alpha': 2.03782292431074e-06, 'reg_lambda': 0.8236705566500369, 'num_leaves': 139}. Best is trial 1 with value: 0.8604461412644544.
# [I 2024-11-27 17:46:45,503] Trial 10 finished with value: 0.8387451583211954 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 6, 'learning_rate': 0.04707223979965029, 'subsample': 0.9762698452070065, 'subsample_freq': 8, 'colsample_bytree': 0.15193792830112873, 'min_child_samples': 8, 'min_child_weight': 0.0022545195857680903, 'reg_alpha': 9.005997579118395, 'reg_lambda': 5.605552124610114e-07, 'num_leaves': 247}. Best is trial 1 with value: 0.8604461412644544.
# [I 2024-11-27 17:46:45,680] Trial 11 finished with value: 0.859460999027214 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 2, 'learning_rate': 0.24791709801320816, 'subsample': 0.5867089863035568, 'subsample_freq': 3, 'colsample_bytree': 0.33875800768070097, 'min_child_samples': 68, 'min_child_weight': 1.2638193817469274, 'reg_alpha': 8.784836838652454e-06, 'reg_lambda': 1.1056599966470863e-05, 'num_leaves': 193}. Best is trial 1 with value: 0.8604461412644544.
# [I 2024-11-27 17:46:45,857] Trial 12 finished with value: 0.8525321234066571 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 2, 'learning_rate': 0.6692242074734954, 'subsample': 0.38929535463348797, 'subsample_freq': 3, 'colsample_bytree': 0.40340957797752364, 'min_child_samples': 63, 'min_child_weight': 0.39035933426027597, 'reg_alpha': 2.171416785579275e-05, 'reg_lambda': 1.8777368009129344e-06, 'num_leaves': 204}. Best is trial 1 with value: 0.8604461412644544.
# [I 2024-11-27 17:46:46,044] Trial 13 finished with value: 0.854469109068272 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 3, 'learning_rate': 0.17038142097030742, 'subsample': 0.6624521446150048, 'subsample_freq': 9, 'colsample_bytree': 0.1277600876302637, 'min_child_samples': 61, 'min_child_weight': 0.0012762258982681731, 'reg_alpha': 2.8744930771977796e-06, 'reg_lambda': 6.2447297217262454e-06, 'num_leaves': 244}. Best is trial 1 with value: 0.8604461412644544.
# [I 2024-11-27 17:46:46,222] Trial 14 finished with value: 0.8312383702848933 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 1, 'learning_rate': 0.047187489240693006, 'subsample': 0.6528238887702509, 'subsample_freq': 4, 'colsample_bytree': 0.27744567227023087, 'min_child_samples': 73, 'min_child_weight': 1.4741676717493912, 'reg_alpha': 0.0012271279874015253, 'reg_lambda': 3.184831197645314e-05, 'num_leaves': 186}. Best is trial 1 with value: 0.8604461412644544.
# [I 2024-11-27 17:46:46,411] Trial 15 finished with value: 0.8605351475252595 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.17976869802325976, 'subsample': 0.38611049574818407, 'subsample_freq': 6, 'colsample_bytree': 0.4200592421907508, 'min_child_samples': 54, 'min_child_weight': 0.10398336927784459, 'reg_alpha': 1.9451148697629555e-06, 'reg_lambda': 5.2548792181209626e-08, 'num_leaves': 107}. Best is trial 15 with value: 0.8605351475252595.
# [I 2024-11-27 17:46:46,603] Trial 16 finished with value: 0.8530327574453738 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.012029973825395338, 'subsample': 0.32050198414516184, 'subsample_freq': 8, 'colsample_bytree': 0.7987106849508309, 'min_child_samples': 49, 'min_child_weight': 0.0913415533028908, 'reg_alpha': 5.306253784944995e-07, 'reg_lambda': 1.9367622818521087e-08, 'num_leaves': 110}. Best is trial 15 with value: 0.8605351475252595.
# [I 2024-11-27 17:46:46,788] Trial 17 finished with value: 0.8613793457306839 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.09207194510245652, 'subsample': 0.4517603955344839, 'subsample_freq': 6, 'colsample_bytree': 0.4460762275894778, 'min_child_samples': 84, 'min_child_weight': 0.003720553646648812, 'reg_alpha': 1.0070880147508553e-09, 'reg_lambda': 1.0640302973292839e-07, 'num_leaves': 97}. Best is trial 17 with value: 0.8613793457306839.
# [I 2024-11-27 17:46:46,985] Trial 18 finished with value: 0.854696232103197 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.020185297128096524, 'subsample': 0.44420244423749067, 'subsample_freq': 7, 'colsample_bytree': 0.4799965618191866, 'min_child_samples': 80, 'min_child_weight': 0.0046855073579779956, 'reg_alpha': 2.6865416558387782e-09, 'reg_lambda': 1.017789613261268e-09, 'num_leaves': 105}. Best is trial 17 with value: 0.8613793457306839.
# [I 2024-11-27 17:46:47,153] Trial 19 finished with value: 0.7663943773174351 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 6, 'learning_rate': 0.9748532570386683, 'subsample': 0.21918377454468602, 'subsample_freq': 6, 'colsample_bytree': 0.6795614618105033, 'min_child_samples': 88, 'min_child_weight': 0.06674221311388001, 'reg_alpha': 5.9596347674961995e-09, 'reg_lambda': 9.497461464603455e-08, 'num_leaves': 63}. Best is trial 17 with value: 0.8613793457306839.
# [I 2024-11-27 17:46:47,309] Trial 20 finished with value: 0.860422894923397 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.07769499787999865, 'subsample': 0.348618805893216, 'subsample_freq': 10, 'colsample_bytree': 0.428238473807118, 'min_child_samples': 58, 'min_child_weight': 0.006634426993225445, 'reg_alpha': 3.053224013986678e-07, 'reg_lambda': 1.2056388654237386e-08, 'num_leaves': 12}. Best is trial 17 with value: 0.8613793457306839.
# [I 2024-11-27 17:46:47,476] Trial 21 finished with value: 0.8591883257294062 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.11386607572945592, 'subsample': 0.5215005118390179, 'subsample_freq': 6, 'colsample_bytree': 0.2068269752253826, 'min_child_samples': 84, 'min_child_weight': 0.0012257841847001904, 'reg_alpha': 0.0021746204165311897, 'reg_lambda': 4.424358473721303e-07, 'num_leaves': 116}. Best is trial 17 with value: 0.8613793457306839.
# [I 2024-11-27 17:46:47,667] Trial 22 finished with value: 0.8498355478440066 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.3020547537548997, 'subsample': 0.40627883438342016, 'subsample_freq': 6, 'colsample_bytree': 0.40599250030055134, 'min_child_samples': 53, 'min_child_weight': 0.0042117131786669135, 'reg_alpha': 0.0002955947924557927, 'reg_lambda': 2.250741079231068e-07, 'num_leaves': 165}. Best is trial 17 with value: 0.8613793457306839.
# [I 2024-11-27 17:46:47,840] Trial 23 finished with value: 0.8568448432390321 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.0765410009980714, 'subsample': 0.28592465345211215, 'subsample_freq': 7, 'colsample_bytree': 0.5157936434178315, 'min_child_samples': 68, 'min_child_weight': 0.0345120709810617, 'reg_alpha': 1.4479638481751875e-08, 'reg_lambda': 1.577140645885904e-08, 'num_leaves': 132}. Best is trial 17 with value: 0.8613793457306839.
# [I 2024-11-27 17:46:48,037] Trial 24 finished with value: 0.83977155757815 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.49394335367062014, 'subsample': 0.6231186755697374, 'subsample_freq': 4, 'colsample_bytree': 0.37492484174207236, 'min_child_samples': 48, 'min_child_weight': 0.007821099535146474, 'reg_alpha': 3.210709964891101e-05, 'reg_lambda': 0.00028430437491025923, 'num_leaves': 94}. Best is trial 17 with value: 0.8613793457306839.
# [I 2024-11-27 17:46:48,194] Trial 25 finished with value: 0.8538776886435342 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.2079089924191403, 'subsample': 0.18366279430741794, 'subsample_freq': 7, 'colsample_bytree': 0.24601781005041576, 'min_child_samples': 35, 'min_child_weight': 0.0032224201151780513, 'reg_alpha': 0.006784529911426184, 'reg_lambda': 1.281572545949592e-06, 'num_leaves': 44}. Best is trial 17 with value: 0.8613793457306839.
# [I 2024-11-27 17:46:48,397] Trial 26 finished with value: 0.8603571350036493 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 6, 'learning_rate': 0.029906823415303468, 'subsample': 0.5018597403677987, 'subsample_freq': 4, 'colsample_bytree': 0.6015808869820658, 'min_child_samples': 55, 'min_child_weight': 0.001041680872006726, 'reg_alpha': 0.48513896417011404, 'reg_lambda': 0.029350286775987423, 'num_leaves': 124}. Best is trial 17 with value: 0.8613793457306839.
# [I 2024-11-27 17:46:48,578] Trial 27 finished with value: 0.8549489051706355 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 5, 'learning_rate': 0.08672310637408588, 'subsample': 0.36834212029301105, 'subsample_freq': 5, 'colsample_bytree': 0.18728322368932648, 'min_child_samples': 68, 'min_child_weight': 0.18107603495355573, 'reg_alpha': 1.170835244268562e-06, 'reg_lambda': 6.032410540308381e-06, 'num_leaves': 65}. Best is trial 17 with value: 0.8613793457306839.
# [I 2024-11-27 17:46:48,757] Trial 28 finished with value: 0.8463968694927375 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.006105119441262303, 'subsample': 0.7166312099205054, 'subsample_freq': 8, 'colsample_bytree': 0.6859954850751429, 'min_child_samples': 86, 'min_child_weight': 0.03687648450275575, 'reg_alpha': 0.00015359899073785774, 'reg_lambda': 5.542364360669112e-09, 'num_leaves': 225}. Best is trial 17 with value: 0.8613793457306839.
# [I 2024-11-27 17:46:48,985] Trial 29 finished with value: 0.8568375133116716 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 6, 'learning_rate': 0.04277006803065826, 'subsample': 0.9762974283083147, 'subsample_freq': 6, 'colsample_bytree': 0.3045793368083213, 'min_child_samples': 78, 'min_child_weight': 0.011201232504264594, 'reg_alpha': 1.3834512426432984e-09, 'reg_lambda': 0.00014131909467923984, 'num_leaves': 91}. Best is trial 17 with value: 0.8613793457306839.
# [I 2024-11-27 17:46:49,170] Trial 30 finished with value: 0.8611326413183817 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.3109423489019778, 'subsample': 0.8582023659146533, 'subsample_freq': 3, 'colsample_bytree': 0.35576433376595634, 'min_child_samples': 23, 'min_child_weight': 0.002010126878591465, 'reg_alpha': 8.96136833761846e-06, 'reg_lambda': 4.028919142592461e-05, 'num_leaves': 170}. Best is trial 17 with value: 0.8613793457306839.
# [I 2024-11-27 17:46:49,344] Trial 31 finished with value: 0.8603340980890879 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.3394036474940717, 'subsample': 0.8500581053198567, 'subsample_freq': 1, 'colsample_bytree': 0.3627631199468466, 'min_child_samples': 13, 'min_child_weight': 0.0022758677618439052, 'reg_alpha': 5.641433265883556e-06, 'reg_lambda': 1.9304534736377865e-05, 'num_leaves': 164}. Best is trial 17 with value: 0.8613793457306839.
# [I 2024-11-27 17:46:49,534] Trial 32 finished with value: 0.8620011329973434 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.17301277362596468, 'subsample': 0.905672397388446, 'subsample_freq': 2, 'colsample_bytree': 0.4611304344699843, 'min_child_samples': 23, 'min_child_weight': 0.002851343681728323, 'reg_alpha': 1.5981409580294436e-05, 'reg_lambda': 2.071835703495272e-06, 'num_leaves': 143}. Best is trial 32 with value: 0.8620011329973434.
# [I 2024-11-27 17:46:49,726] Trial 33 finished with value: 0.8567931148945171 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.5756201756709811, 'subsample': 0.8349899493974119, 'subsample_freq': 3, 'colsample_bytree': 0.4910063379271997, 'min_child_samples': 20, 'min_child_weight': 0.014255852245997135, 'reg_alpha': 5.219234412753069e-07, 'reg_lambda': 1.0302102342172959e-07, 'num_leaves': 142}. Best is trial 32 with value: 0.8620011329973434.
# [I 2024-11-27 17:46:49,908] Trial 34 finished with value: 0.8619282525767312 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.1783945444725517, 'subsample': 0.9287095733540872, 'subsample_freq': 2, 'colsample_bytree': 0.44073200114857997, 'min_child_samples': 22, 'min_child_weight': 0.0024612737942823256, 'reg_alpha': 1.46133755692862e-07, 'reg_lambda': 1.4907613431841325e-06, 'num_leaves': 171}. Best is trial 32 with value: 0.8620011329973434.
# [I 2024-11-27 17:46:50,102] Trial 35 finished with value: 0.8614813364342415 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.1123956045007087, 'subsample': 0.9207321735996604, 'subsample_freq': 2, 'colsample_bytree': 0.5421327915883007, 'min_child_samples': 21, 'min_child_weight': 0.0024076528752119126, 'reg_alpha': 1.4137208426955669e-07, 'reg_lambda': 3.7058028426629896e-05, 'num_leaves': 172}. Best is trial 32 with value: 0.8620011329973434.
# [I 2024-11-27 17:46:50,270] Trial 36 finished with value: 0.8478408651827403 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 1, 'learning_rate': 0.11056741212029574, 'subsample': 0.9328425216296643, 'subsample_freq': 1, 'colsample_bytree': 0.5437897177997696, 'min_child_samples': 16, 'min_child_weight': 0.007498655221446206, 'reg_alpha': 1.48851794844822e-07, 'reg_lambda': 2.139181202370487e-06, 'num_leaves': 156}. Best is trial 32 with value: 0.8620011329973434.
# [I 2024-11-27 17:46:50,438] Trial 37 finished with value: 0.8590584813018789 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.07619351409358156, 'subsample': 0.7752177090262911, 'subsample_freq': 2, 'colsample_bytree': 0.6461476307129868, 'min_child_samples': 30, 'min_child_weight': 0.023366486240213383, 'reg_alpha': 1.993438736129408e-08, 'reg_lambda': 0.0005663415733050114, 'num_leaves': 214}. Best is trial 32 with value: 0.8620011329973434.
# [I 2024-11-27 17:46:50,631] Trial 38 finished with value: 0.8570715474209651 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 2, 'learning_rate': 0.1379553720498625, 'subsample': 0.9214360334722662, 'subsample_freq': 2, 'colsample_bytree': 0.44363539987844863, 'min_child_samples': 10, 'min_child_weight': 0.0035369439642742714, 'reg_alpha': 6.485981248051118e-09, 'reg_lambda': 4.700937806066142e-05, 'num_leaves': 174}. Best is trial 32 with value: 0.8620011329973434.
# [I 2024-11-27 17:46:50,814] Trial 39 finished with value: 0.8507724172739163 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.028923766337150995, 'subsample': 0.9004281446233757, 'subsample_freq': 5, 'colsample_bytree': 0.558083183386954, 'min_child_samples': 5, 'min_child_weight': 0.010887377126196213, 'reg_alpha': 8.961484289384897e-08, 'reg_lambda': 8.009990836217135, 'num_leaves': 149}. Best is trial 32 with value: 0.8620011329973434.
# [I 2024-11-27 17:46:50,990] Trial 40 finished with value: 0.8508594339830091 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 2, 'learning_rate': 0.04987255353490513, 'subsample': 0.7326245703869477, 'subsample_freq': 0, 'colsample_bytree': 0.4743668926920782, 'min_child_samples': 25, 'min_child_weight': 0.002024050540079019, 'reg_alpha': 2.359054412081854e-08, 'reg_lambda': 4.2145929003196044e-07, 'num_leaves': 124}. Best is trial 32 with value: 0.8620011329973434.
# [I 2024-11-27 17:46:51,198] Trial 41 finished with value: 0.8620738039914596 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.25208650792770265, 'subsample': 0.9994638891044645, 'subsample_freq': 2, 'colsample_bytree': 0.5276677120232547, 'min_child_samples': 17, 'min_child_weight': 0.0020352261436055725, 'reg_alpha': 1.6370869866398043e-05, 'reg_lambda': 0.00014006428404717824, 'num_leaves': 174}. Best is trial 41 with value: 0.8620738039914596.
# [I 2024-11-27 17:46:51,371] Trial 42 finished with value: 0.8636470158295017 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.21760157115085355, 'subsample': 0.9998222215287221, 'subsample_freq': 1, 'colsample_bytree': 0.5177129111089653, 'min_child_samples': 20, 'min_child_weight': 0.005255694586052964, 'reg_alpha': 5.449321433836635e-05, 'reg_lambda': 0.012999078108824948, 'num_leaves': 198}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:51,528] Trial 43 finished with value: 0.861960713683613 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.2304293623198874, 'subsample': 0.9826767409647077, 'subsample_freq': 1, 'colsample_bytree': 0.755854555377233, 'min_child_samples': 19, 'min_child_weight': 0.0061244715334341955, 'reg_alpha': 7.868984261600054e-05, 'reg_lambda': 0.01934554788860311, 'num_leaves': 195}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:51,680] Trial 44 finished with value: 0.8632727706811283 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.22920255798981023, 'subsample': 0.9980497089387289, 'subsample_freq': 0, 'colsample_bytree': 0.7807094277218352, 'min_child_samples': 17, 'min_child_weight': 0.006233930975357839, 'reg_alpha': 5.5908027376256746e-05, 'reg_lambda': 0.018121827188057753, 'num_leaves': 204}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:51,846] Trial 45 finished with value: 0.8578123936506076 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 2, 'learning_rate': 0.8534252518822263, 'subsample': 0.9927100296343139, 'subsample_freq': 1, 'colsample_bytree': 0.8169415366803287, 'min_child_samples': 34, 'min_child_weight': 0.017962053935288665, 'reg_alpha': 4.4553088719614e-05, 'reg_lambda': 0.018070342075900383, 'num_leaves': 230}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:52,043] Trial 46 finished with value: 0.8560525828046187 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.40885398356600805, 'subsample': 0.9647393521952574, 'subsample_freq': 0, 'colsample_bytree': 0.928694131803409, 'min_child_samples': 15, 'min_child_weight': 0.006434100524435354, 'reg_alpha': 0.00029905137534748686, 'reg_lambda': 0.12717209724446768, 'num_leaves': 202}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:52,197] Trial 47 finished with value: 0.8608957799513921 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 2, 'learning_rate': 0.23575363319619003, 'subsample': 0.8204238527349653, 'subsample_freq': 0, 'colsample_bytree': 0.812215789856744, 'min_child_samples': 18, 'min_child_weight': 0.026173331849797525, 'reg_alpha': 1.6578275173809238e-05, 'reg_lambda': 0.006092534695039463, 'num_leaves': 191}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:52,357] Trial 48 finished with value: 0.8315778506349287 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.0010490228137166279, 'subsample': 0.869375626646886, 'subsample_freq': 1, 'colsample_bytree': 0.8788685413448688, 'min_child_samples': 28, 'min_child_weight': 13.63876502961751, 'reg_alpha': 8.684149299166234e-05, 'reg_lambda': 0.0016639892984992289, 'num_leaves': 213}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:52,555] Trial 49 finished with value: 0.8573187753995072 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 3, 'learning_rate': 0.41623905363472474, 'subsample': 0.9555059751858427, 'subsample_freq': 1, 'colsample_bytree': 0.740298027795176, 'min_child_samples': 11, 'min_child_weight': 0.05171594835713262, 'reg_alpha': 0.004498867665786582, 'reg_lambda': 0.20222673424458898, 'num_leaves': 181}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:52,716] Trial 50 finished with value: 0.8564691321051865 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.7035928989530406, 'subsample': 0.9979716034141275, 'subsample_freq': 0, 'colsample_bytree': 0.6350307289654741, 'min_child_samples': 39, 'min_child_weight': 52.03053051063037, 'reg_alpha': 0.0002725188592384341, 'reg_lambda': 0.014982016482910776, 'num_leaves': 197}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:52,894] Trial 51 finished with value: 0.8631969582895719 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.16326522344708141, 'subsample': 0.8859297055492441, 'subsample_freq': 2, 'colsample_bytree': 0.7774591576645767, 'min_child_samples': 25, 'min_child_weight': 0.0016215233832510185, 'reg_alpha': 0.0005388614106246848, 'reg_lambda': 0.038787304282595025, 'num_leaves': 233}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:53,060] Trial 52 finished with value: 0.8626520305469486 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.21333853316931234, 'subsample': 0.8972094661269203, 'subsample_freq': 1, 'colsample_bytree': 0.759857597053408, 'min_child_samples': 6, 'min_child_weight': 0.0014509872625916998, 'reg_alpha': 0.0006967211333630127, 'reg_lambda': 0.062435069834966224, 'num_leaves': 235}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:53,218] Trial 53 finished with value: 0.8585989995696286 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 2, 'learning_rate': 0.13989406065560922, 'subsample': 0.8895976935998701, 'subsample_freq': 2, 'colsample_bytree': 0.862674640986824, 'min_child_samples': 7, 'min_child_weight': 0.0014595328252727977, 'reg_alpha': 0.0007350795661944458, 'reg_lambda': 0.07543112922381101, 'num_leaves': 252}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:53,396] Trial 54 finished with value: 0.8610549440883613 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.3128711451900935, 'subsample': 0.7781186579865479, 'subsample_freq': 3, 'colsample_bytree': 0.6714695206945975, 'min_child_samples': 32, 'min_child_weight': 0.0010038948351938813, 'reg_alpha': 0.028439681253882486, 'reg_lambda': 1.1742970244731752, 'num_leaves': 232}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:53,558] Trial 55 finished with value: 0.8585953346059483 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.06045848287453555, 'subsample': 0.8898236699799073, 'subsample_freq': 0, 'colsample_bytree': 0.7805837030970537, 'min_child_samples': 26, 'min_child_weight': 0.00182818724952626, 'reg_alpha': 4.530504917440234e-06, 'reg_lambda': 0.3296309316674199, 'num_leaves': 240}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:53,766] Trial 56 finished with value: 0.86071944284175 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 4, 'learning_rate': 0.1948299572500744, 'subsample': 0.9495586702416006, 'subsample_freq': 1, 'colsample_bytree': 0.7216473794022524, 'min_child_samples': 14, 'min_child_weight': 0.004989981843338357, 'reg_alpha': 0.0020560682336296515, 'reg_lambda': 0.06344547824072336, 'num_leaves': 233}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:53,933] Trial 57 finished with value: 0.8584851762690461 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 2, 'learning_rate': 0.15121578808891784, 'subsample': 0.9467074082836586, 'subsample_freq': 2, 'colsample_bytree': 0.8542937815359289, 'min_child_samples': 9, 'min_child_weight': 0.719797593843872, 'reg_alpha': 2.0511686271156612e-05, 'reg_lambda': 0.0039317776524696035, 'num_leaves': 210}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:54,107] Trial 58 finished with value: 0.8578693576575227 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.5488009221842176, 'subsample': 0.800797468722457, 'subsample_freq': 3, 'colsample_bytree': 0.9750820203657136, 'min_child_samples': 17, 'min_child_weight': 0.003283210572394118, 'reg_alpha': 0.00017572089664297786, 'reg_lambda': 0.007756701470060439, 'num_leaves': 222}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:54,288] Trial 59 finished with value: 0.8612503390091404 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.2759754093394001, 'subsample': 0.889642375335825, 'subsample_freq': 1, 'colsample_bytree': 0.5900925395958212, 'min_child_samples': 38, 'min_child_weight': 0.008564985316189098, 'reg_alpha': 0.0006203971389193808, 'reg_lambda': 0.0008910063059235213, 'num_leaves': 256}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:54,459] Trial 60 finished with value: 0.862621454278531 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.4401112411458433, 'subsample': 0.9945543180035972, 'subsample_freq': 2, 'colsample_bytree': 0.7031134878849152, 'min_child_samples': 5, 'min_child_weight': 3.8629846934018635, 'reg_alpha': 4.437555850830129e-05, 'reg_lambda': 2.2493301929770633, 'num_leaves': 185}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:54,632] Trial 61 finished with value: 0.8625827103767689 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.3928749301637928, 'subsample': 0.9944549159871412, 'subsample_freq': 2, 'colsample_bytree': 0.7114694921675631, 'min_child_samples': 5, 'min_child_weight': 4.3218275259334185, 'reg_alpha': 5.324491768303059e-05, 'reg_lambda': 2.3215910843426717, 'num_leaves': 184}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:54,785] Trial 62 finished with value: 0.8624304573141679 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.36961712580199296, 'subsample': 0.9927873100550237, 'subsample_freq': 0, 'colsample_bytree': 0.7767071342742878, 'min_child_samples': 5, 'min_child_weight': 5.952353466372859, 'reg_alpha': 5.9265759902898984e-05, 'reg_lambda': 1.8304254003916078, 'num_leaves': 206}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:54,931] Trial 63 finished with value: 0.8629152796524358 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 2, 'learning_rate': 0.45647238257456463, 'subsample': 0.9490873016832823, 'subsample_freq': 0, 'colsample_bytree': 0.7710018190315355, 'min_child_samples': 8, 'min_child_weight': 4.753424828876237, 'reg_alpha': 4.7102177745988315e-05, 'reg_lambda': 2.6822215857276506, 'num_leaves': 206}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:55,089] Trial 64 finished with value: 0.8593250812313021 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 2, 'learning_rate': 0.6952313513369336, 'subsample': 0.9569393929664661, 'subsample_freq': 0, 'colsample_bytree': 0.7109040146128398, 'min_child_samples': 12, 'min_child_weight': 2.761831890350201, 'reg_alpha': 0.0005563094882763929, 'reg_lambda': 4.164546264382619, 'num_leaves': 241}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:55,244] Trial 65 finished with value: 0.8538959087486871 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 1, 'learning_rate': 0.49097003649016674, 'subsample': 0.8622392146305762, 'subsample_freq': 1, 'colsample_bytree': 0.8327098275242567, 'min_child_samples': 8, 'min_child_weight': 5.073023511931441, 'reg_alpha': 0.004523482907160219, 'reg_lambda': 0.40519819504226234, 'num_leaves': 221}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:55,455] Trial 66 finished with value: 0.859811578981538 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 2, 'learning_rate': 0.4373330027341364, 'subsample': 0.9580561810277893, 'subsample_freq': 1, 'colsample_bytree': 0.9121354301496489, 'min_child_samples': 5, 'min_child_weight': 7.706884343695247, 'reg_alpha': 0.0001333741190800847, 'reg_lambda': 2.927353487754996, 'num_leaves': 201}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:55,617] Trial 67 finished with value: 0.8594551350853256 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 2, 'learning_rate': 0.281428336479122, 'subsample': 0.8274292906580946, 'subsample_freq': 0, 'colsample_bytree': 0.6270051430936883, 'min_child_samples': 12, 'min_child_weight': 26.29629397696657, 'reg_alpha': 3.644836384221344e-05, 'reg_lambda': 9.292964532190252, 'num_leaves': 184}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:55,806] Trial 68 finished with value: 0.8441621840670415 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.7514351253485922, 'subsample': 0.9220772806590782, 'subsample_freq': 3, 'colsample_bytree': 0.6977889934013685, 'min_child_samples': 8, 'min_child_weight': 2.550314529928209, 'reg_alpha': 0.0010547357324552837, 'reg_lambda': 0.9907353188363516, 'num_leaves': 188}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:55,975] Trial 69 finished with value: 0.8547558139413124 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.6030328591479056, 'subsample': 0.8690337160900711, 'subsample_freq': 4, 'colsample_bytree': 0.7471980650101975, 'min_child_samples': 13, 'min_child_weight': 1.166477706893426, 'reg_alpha': 0.011020476946014275, 'reg_lambda': 0.06019676355921905, 'num_leaves': 215}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:56,140] Trial 70 finished with value: 0.8380738416882291 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.004507701558422426, 'subsample': 0.9701087770228664, 'subsample_freq': 0, 'colsample_bytree': 0.7793073180384278, 'min_child_samples': 10, 'min_child_weight': 26.345837378444486, 'reg_alpha': 8.74791500983043e-06, 'reg_lambda': 0.2105687642229837, 'num_leaves': 238}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:56,301] Trial 71 finished with value: 0.8617709732782263 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.34481094563413817, 'subsample': 0.9947195613538014, 'subsample_freq': 0, 'colsample_bytree': 0.7771311268370992, 'min_child_samples': 6, 'min_child_weight': 8.630634920846317, 'reg_alpha': 5.2938352050124526e-05, 'reg_lambda': 1.954991086266263, 'num_leaves': 208}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:56,469] Trial 72 finished with value: 0.8603016369822061 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.3426757682085908, 'subsample': 0.9373056747992106, 'subsample_freq': 0, 'colsample_bytree': 0.6621143486531335, 'min_child_samples': 5, 'min_child_weight': 3.3351184505934786, 'reg_alpha': 0.00031303269788266386, 'reg_lambda': 1.0744601598798733, 'num_leaves': 204}. Best is trial 42 with value: 0.8636470158295017.
# [I 2024-11-27 17:46:56,633] Trial 73 finished with value: 0.86396534410344 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.21536181645382924, 'subsample': 0.9033986669350814, 'subsample_freq': 1, 'colsample_bytree': 0.7633229121445825, 'min_child_samples': 15, 'min_child_weight': 1.7954569541613403, 'reg_alpha': 9.433842186158298e-05, 'reg_lambda': 0.5575771667314159, 'num_leaves': 222}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:56,796] Trial 74 finished with value: 0.8393267357006207 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.9659656975904296, 'subsample': 0.9092155434763732, 'subsample_freq': 1, 'colsample_bytree': 0.7319241659905645, 'min_child_samples': 15, 'min_child_weight': 0.9026078695917027, 'reg_alpha': 1.5899293771366188e-06, 'reg_lambda': 0.5034819892066984, 'num_leaves': 227}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:56,949] Trial 75 finished with value: 0.851169175770611 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 1, 'learning_rate': 0.20858589119627158, 'subsample': 0.8384602072620422, 'subsample_freq': 2, 'colsample_bytree': 0.7028868236433782, 'min_child_samples': 20, 'min_child_weight': 0.21259762680411481, 'reg_alpha': 0.00013646386814486567, 'reg_lambda': 4.108883720425416, 'num_leaves': 246}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:57,124] Trial 76 finished with value: 0.8491484195105912 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.5010443830903022, 'subsample': 0.9345072492117018, 'subsample_freq': 1, 'colsample_bytree': 0.8955827855947993, 'min_child_samples': 10, 'min_child_weight': 1.708306139462767, 'reg_alpha': 0.0013002705468407557, 'reg_lambda': 0.1477035508952231, 'num_leaves': 215}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:57,297] Trial 77 finished with value: 0.861190652457777 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.15954899870741665, 'subsample': 0.7448628230968707, 'subsample_freq': 1, 'colsample_bytree': 0.8368917729736981, 'min_child_samples': 24, 'min_child_weight': 2.356866753515024, 'reg_alpha': 7.063099348964813e-06, 'reg_lambda': 0.035681194565212036, 'num_leaves': 196}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:57,471] Trial 78 finished with value: 0.8582358540255437 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 2, 'learning_rate': 0.11575556630144457, 'subsample': 0.6898793326994896, 'subsample_freq': 2, 'colsample_bytree': 0.7900732130965782, 'min_child_samples': 14, 'min_child_weight': 3.632037476970311, 'reg_alpha': 0.00033932035884050744, 'reg_lambda': 0.34494203634271153, 'num_leaves': 220}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:57,633] Trial 79 finished with value: 0.8521689778625722 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.22033374334936473, 'subsample': 0.10293682135002319, 'subsample_freq': 2, 'colsample_bytree': 0.5684191229995815, 'min_child_samples': 19, 'min_child_weight': 0.6119588419533608, 'reg_alpha': 2.8112089241590186e-05, 'reg_lambda': 0.6550686543938367, 'num_leaves': 163}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:57,844] Trial 80 finished with value: 0.8611723276393759 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 3, 'learning_rate': 0.09531207441133287, 'subsample': 0.9683492422086174, 'subsample_freq': 3, 'colsample_bytree': 0.7605510807493128, 'min_child_samples': 8, 'min_child_weight': 8.269754063932936, 'reg_alpha': 3.6850148836924975e-06, 'reg_lambda': 2.359198770861094, 'num_leaves': 180}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:57,992] Trial 81 finished with value: 0.8630139195320574 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.37170853354137473, 'subsample': 0.9756809636114991, 'subsample_freq': 0, 'colsample_bytree': 0.7672178749592823, 'min_child_samples': 5, 'min_child_weight': 1.8270961087892725, 'reg_alpha': 6.687468001141545e-05, 'reg_lambda': 6.704417985114869, 'num_leaves': 204}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:58,156] Trial 82 finished with value: 0.8625025000287961 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.2672251357093094, 'subsample': 0.9040537044850966, 'subsample_freq': 1, 'colsample_bytree': 0.8093221165372209, 'min_child_samples': 11, 'min_child_weight': 1.7079023984862447, 'reg_alpha': 9.850197543895599e-05, 'reg_lambda': 3.961442435365332, 'num_leaves': 190}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:58,332] Trial 83 finished with value: 0.8610367239832082 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.19266728631943544, 'subsample': 0.9687549646707658, 'subsample_freq': 1, 'colsample_bytree': 0.6179604911642768, 'min_child_samples': 16, 'min_child_weight': 5.057853632309354, 'reg_alpha': 1.250832509574594e-05, 'reg_lambda': 6.622804178059371, 'num_leaves': 234}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:58,489] Trial 84 finished with value: 0.8566000236651942 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.41241447202065445, 'subsample': 0.583696393756495, 'subsample_freq': 0, 'colsample_bytree': 0.7565091817412368, 'min_child_samples': 8, 'min_child_weight': 18.28337843183684, 'reg_alpha': 0.00022031539212474916, 'reg_lambda': 0.010698109792888228, 'num_leaves': 224}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:58,650] Trial 85 finished with value: 0.8528810279490132 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.5904635820758182, 'subsample': 0.9370182036703176, 'subsample_freq': 0, 'colsample_bytree': 0.6555135571514348, 'min_child_samples': 12, 'min_child_weight': 0.33903144974142835, 'reg_alpha': 5.60731885456114e-05, 'reg_lambda': 0.0030061448870783774, 'num_leaves': 200}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:58,840] Trial 86 finished with value: 0.8605294930098673 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.2974895292000655, 'subsample': 0.9777758340981828, 'subsample_freq': 1, 'colsample_bytree': 0.5042134281139706, 'min_child_samples': 46, 'min_child_weight': 0.0014418873204202697, 'reg_alpha': 0.0004833056487368712, 'reg_lambda': 1.4649207928963144, 'num_leaves': 218}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:59,002] Trial 87 finished with value: 0.8594042444467948 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 3, 'learning_rate': 0.46529163070428337, 'subsample': 0.877043928932475, 'subsample_freq': 1, 'colsample_bytree': 0.6876317224944191, 'min_child_samples': 22, 'min_child_weight': 1.9891430304480682, 'reg_alpha': 3.0073707670299257e-05, 'reg_lambda': 0.037932854980082545, 'num_leaves': 209}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:59,163] Trial 88 finished with value: 0.8633749708111822 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.24703764898590247, 'subsample': 0.912552770788778, 'subsample_freq': 0, 'colsample_bytree': 0.7232593187709593, 'min_child_samples': 17, 'min_child_weight': 1.292284359893834, 'reg_alpha': 0.0019585065785489115, 'reg_lambda': 5.550140118687036, 'num_leaves': 181}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:59,328] Trial 89 finished with value: 0.8626225014110112 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.1258151851090212, 'subsample': 0.8025855738328096, 'subsample_freq': 0, 'colsample_bytree': 0.8407278431568036, 'min_child_samples': 26, 'min_child_weight': 1.303450294821699, 'reg_alpha': 0.002213709660109514, 'reg_lambda': 6.500691256804335, 'num_leaves': 191}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:59,491] Trial 90 finished with value: 0.8638505783836253 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.1279595035963877, 'subsample': 0.812096958941681, 'subsample_freq': 0, 'colsample_bytree': 0.8347707576704575, 'min_child_samples': 31, 'min_child_weight': 0.5117843000951399, 'reg_alpha': 0.0023563437223464217, 'reg_lambda': 5.123193919051106, 'num_leaves': 228}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:59,663] Trial 91 finished with value: 0.8627309843359453 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.15361478845628637, 'subsample': 0.7994171560265011, 'subsample_freq': 0, 'colsample_bytree': 0.834993026983608, 'min_child_samples': 27, 'min_child_weight': 1.01138446978984, 'reg_alpha': 0.10694394703159964, 'reg_lambda': 6.126280041022028, 'num_leaves': 227}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:46:59,839] Trial 92 finished with value: 0.8630516163013396 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.1621764049595038, 'subsample': 0.8497866105620205, 'subsample_freq': 0, 'colsample_bytree': 0.9466349734542238, 'min_child_samples': 30, 'min_child_weight': 0.5544870365615622, 'reg_alpha': 0.16587484176130882, 'reg_lambda': 0.7649907852135289, 'num_leaves': 228}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:47:00,023] Trial 93 finished with value: 0.8613596596400588 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.10094178829255579, 'subsample': 0.8461739381615186, 'subsample_freq': 0, 'colsample_bytree': 0.9404331729565341, 'min_child_samples': 31, 'min_child_weight': 0.19036550891098128, 'reg_alpha': 0.5540838450603046, 'reg_lambda': 9.894483893677341, 'num_leaves': 247}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:47:00,186] Trial 94 finished with value: 0.8635890046901062 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.15849398371064913, 'subsample': 0.7573101267285852, 'subsample_freq': 0, 'colsample_bytree': 0.9735104262750311, 'min_child_samples': 27, 'min_child_weight': 0.5369804078896627, 'reg_alpha': 0.46871776745016464, 'reg_lambda': 5.554997274289355, 'num_leaves': 226}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:47:00,349] Trial 95 finished with value: 0.8628553836745764 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.16941298386066916, 'subsample': 0.750654135004481, 'subsample_freq': 0, 'colsample_bytree': 0.9658937919962847, 'min_child_samples': 34, 'min_child_weight': 0.5220435220584727, 'reg_alpha': 2.2173073315693794, 'reg_lambda': 0.8674261619438133, 'num_leaves': 228}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:47:00,514] Trial 96 finished with value: 0.8608048888521229 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.07204724650054461, 'subsample': 0.8140104001630558, 'subsample_freq': 0, 'colsample_bytree': 0.9467688099184484, 'min_child_samples': 37, 'min_child_weight': 0.2333796345237357, 'reg_alpha': 0.12172918412327971, 'reg_lambda': 3.748549219861936, 'num_leaves': 212}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:47:00,678] Trial 97 finished with value: 0.8611077195653563 and parameters: {'encoders': 'OrdinalEncoder', 'max_depth': 4, 'learning_rate': 0.2625087459369515, 'subsample': 0.7725210214127538, 'subsample_freq': 0, 'colsample_bytree': 0.9936375458632793, 'min_child_samples': 42, 'min_child_weight': 0.4156160774652113, 'reg_alpha': 0.35387409772785344, 'reg_lambda': 0.25418797117194747, 'num_leaves': 253}. Best is trial 73 with value: 0.86396534410344.
# [I 2024-11-27 17:47:00,922] Trial 98 finished with value: 0.8658093444008256 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 5, 'learning_rate': 0.12308857182346723, 'subsample': 0.916553990715227, 'subsample_freq': 0, 'colsample_bytree': 0.8672065256050777, 'min_child_samples': 22, 'min_child_weight': 0.856992960312687, 'reg_alpha': 0.024875317016880637, 'reg_lambda': 0.6004171209430826, 'num_leaves': 220}. Best is trial 98 with value: 0.8658093444008256.
# [I 2024-11-27 17:47:01,146] Trial 99 finished with value: 0.8608283446196763 and parameters: {'encoders': 'TargetEncoder', 'max_depth': 5, 'learning_rate': 0.12768805427725852, 'subsample': 0.8744393521096351, 'subsample_freq': 0, 'colsample_bytree': 0.8845832769812197, 'min_child_samples': 30, 'min_child_weight': 0.7465186792179371, 'reg_alpha': 0.03438030386641818, 'reg_lambda': 0.7213067057709672, 'num_leaves': 242}. Best is trial 98 with value: 0.8658093444008256.

# %%
print("Number of finished trials: {}".format(len(study_seas.trials)))
print("Best trial:")
trial_seas = study_seas.best_trial

print("  Value: {}".format(trial_seas.value))

print("  Params: ")
for key, value in trial_seas.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Number of finished trials: 100
# Best trial:
#   Value: 0.8658093444008256
#   Params:
#     encoders: TargetEncoder
#     max_depth: 5
#     learning_rate: 0.12308857182346723
#     subsample: 0.916553990715227
#     subsample_freq: 0
#     colsample_bytree: 0.8672065256050777
#     min_child_samples: 22
#     min_child_weight: 0.856992960312687
#     reg_alpha: 0.024875317016880637
#     reg_lambda: 0.6004171209430826
#     num_leaves: 220

# %% [markdown]
# **Werte mit dem Versuch für Pruner**
#
# Number of finished trials: 100
#
# Best trial:
#
#   Value: 0.8657634799981989
#
#   Params:
#
#     encoders: TargetEncoder
#     max_depth: 6
#     learning_rate: 0.06115118796155541
#     subsample: 0.9051437761260196
#     subsample_freq: 8
#     colsample_bytree: 0.8925410506480986
#     min_child_samples: 31
#     min_child_weight: 0.19653456438533892
#     reg_alpha: 0.00545284829993156
#     reg_lambda: 0.0005242068931854741
#     num_leaves: 249

# %% [markdown]
# # Submission Data

# %%
df_test_set_features = pd.read_csv('Data/test_set_features.csv', index_col='respondent_id')
#df_test_set_features=df_test_set_features[:].astype("category")

# %%
def objective_predict_proba_h1n1(trial):
    '''First select the encoder'''
    encoders = trial.suggest_categorical("encoders", ["TargetEncoder", "OrdinalEncoder"])

    if encoders == "TargetEncoder":
        encoder = TargetEncoder()
    else:
        encoder = OrdinalEncoder()
    
    '''2nd select the model LGBM-model'''
    # instantiate parameters for classifier
    params = {
        'objective': 'binary', # i the previous 2 files I didn't explicitly define this, as LGBM would use this as default for the classifier
        'metric': 'auc',
        'verbosity': 0,
        'max_depth': trial.suggest_int('max_depth', 1, 6),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 1.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'subsample_freq': trial.suggest_int('subsample_freq', 0, 10),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        'min_child_weight': trial.suggest_float('min_child_weight', 0.001, 100, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-9, 10.0, log=True), # in LGBM; the value is not limited to [0 to 1] also knwon as lambda_l1
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-9, 10.0, log=True), # in LGBM ; the value is not limited to [0 to 1] also knwon as lambda_l2
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "random_state": 8,
        #"n_jobs": 1
    }

    #classifier = lgb.LGBMClassifier(**params, callbacks=[optuna.integration.LightGBMPruningCallback(trial, "auc")])
    classifier = lgb.LGBMClassifier(**params)

    pipe = Pipeline([('encoder', encoder), 
                     ('clf', classifier)])
    pipe.fit(X_train1, np.ravel(y_train1))

    return pipe.predict_proba(df_test_set_features)[:,1]

# %%
def objective_predict_proba_seas(trial):
    '''First select the encoder'''
    encoders = trial.suggest_categorical("encoders", ["TargetEncoder", "OrdinalEncoder"])

    if encoders == "TargetEncoder":
        encoder = TargetEncoder()
    else:
        encoder = OrdinalEncoder()
    
    '''2nd select the model LGBM-model'''
    # instantiate parameters for classifier
    params = {
        'objective': 'binary', # i the previous 2 files I didn't explicitly define this, as LGBM would use this as default for the classifier
        'metric': 'auc',
        'verbosity': 0,
        'max_depth': trial.suggest_int('max_depth', 1, 6),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 1.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'subsample_freq': trial.suggest_int('subsample_freq', 0, 10),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        'min_child_weight': trial.suggest_float('min_child_weight', 0.001, 100, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-9, 10.0, log=True), # in LGBM; the value is not limited to [0 to 1] also knwon as lambda_l1
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-9, 10.0, log=True), # in LGBM ; the value is not limited to [0 to 1] also knwon as lambda_l2
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "random_state": 8,
        #"n_jobs": 1
    }

    #classifier = lgb.LGBMClassifier(**params, callbacks=[optuna.integration.LightGBMPruningCallback(trial, "auc")])
    classifier = lgb.LGBMClassifier(**params)

    pipe = Pipeline([('encoder', encoder), 
                     ('clf', classifier)])
    pipe.fit(X_train1, np.ravel(y_train1))

    return pipe.predict_proba(df_test_set_features)[:,1]

# %%
h1n1_vaccine_probability = objective_predict_proba_h1n1(study_h1n1.best_trial)

# %%
seas_vaccine_probability = objective_predict_proba_seas(study_seas.best_trial)

# %%
df_submission = df_test_set_features[[]]
df_submission['h1n1_vaccine'] = h1n1_vaccine_probability.tolist()
df_submission['seasonal_vaccine'] = seas_vaccine_probability.tolist()
# Out:
# C:\Users\sager\AppData\Local\Temp\ipykernel_26084\1917870352.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_submission['h1n1_vaccine'] = h1n1_vaccine_probability.tolist()
# C:\Users\sager\AppData\Local\Temp\ipykernel_26084\1917870352.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_submission['seasonal_vaccine'] = seas_vaccine_probability.tolist()

# %%
df_submission.to_csv("LGBM_Model/Optuna_Pipeline_submission.csv")
