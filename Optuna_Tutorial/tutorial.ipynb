# %%
from sklearn.datasets import load_breast_cancer
import optuna
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score

# -- Get the dataset
X, y = load_breast_cancer(return_X_y=True)

# -- Define the objective function
def objective(trial):
    # -- Instantiate scaler
    # (a) List scalers to chose from
    scalers = trial.suggest_categorical("scalers", ['minmax', 'standard', 'robust'])

    # (b) Define your scalers
    if scalers == "minmax":
        scaler = MinMaxScaler()
    elif scalers == "standard":
        scaler = StandardScaler()
    else:
        scaler = RobustScaler()

    # -- Instantiate dimensionality reduction
     # (a) List all dimensionality reduction options
    dim_red = trial.suggest_categorical("dim_red", ["PCA", None])

    # (b) Define the PCA algorithm and its hyperparameters
    if dim_red == "PCA":
        pca_n_components=trial.suggest_int("pca_n_components", 2, 30) # suggest an integer from 2 to 30
        dimen_red_algorithm=PCA(n_components=pca_n_components)
    # (c) No dimensionality reduction option
    else:
        dimen_red_algorithm='passthrough'

    # -- Instantiate estimator model
    knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
    knn_metric=trial.suggest_categorical("knn_metric", ['euclidean', 'manhattan', 'minkowski'])
    knn_weights=trial.suggest_categorical("knn_weights", ['uniform', 'distance'])

    estimator=KNeighborsClassifier(n_neighbors=knn_n_neighbors, metric=knn_metric, weights=knn_weights)

    # -- Make a pipeline
    pipeline = make_pipeline(scaler, dimen_red_algorithm, estimator)

    # -- Evaluate the score by cross-validation
    score = cross_val_score(pipeline, X, y, scoring='f1')
    f1 = score.mean() # calculate the mean of scores
    return f1

study = optuna.create_study(direction="maximize") # maximise the score during tuning
study.optimize(objective, n_trials=100) # run the objective function 100 times

print(study.best_trial) # print the best performing pipeline
# Out:
# [I 2024-11-25 17:12:23,227] A new study created in memory with name: no-name-fb38e9c8-2708-4c7d-b1be-b57badbf9725
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,264] Trial 0 finished with value: 0.9667700701135352 and parameters: {'scalers': 'standard', 'dim_red': 'PCA', 'pca_n_components': 5, 'knn_n_neighbors': 5, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 0 with value: 0.9667700701135352.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,290] Trial 1 finished with value: 0.9766010241340217 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 24, 'knn_n_neighbors': 9, 'knn_metric': 'minkowski', 'knn_weights': 'distance'}. Best is trial 1 with value: 0.9766010241340217.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,312] Trial 2 finished with value: 0.9524738248147026 and parameters: {'scalers': 'standard', 'dim_red': 'PCA', 'pca_n_components': 2, 'knn_n_neighbors': 13, 'knn_metric': 'manhattan', 'knn_weights': 'distance'}. Best is trial 1 with value: 0.9766010241340217.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,333] Trial 3 finished with value: 0.9751637020083684 and parameters: {'scalers': 'minmax', 'dim_red': None, 'knn_n_neighbors': 3, 'knn_metric': 'euclidean', 'knn_weights': 'distance'}. Best is trial 1 with value: 0.9766010241340217.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,370] Trial 4 finished with value: 0.9687208908895562 and parameters: {'scalers': 'robust', 'dim_red': None, 'knn_n_neighbors': 17, 'knn_metric': 'euclidean', 'knn_weights': 'distance'}. Best is trial 1 with value: 0.9766010241340217.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,396] Trial 5 finished with value: 0.9739613452056937 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 19, 'knn_n_neighbors': 19, 'knn_metric': 'euclidean', 'knn_weights': 'distance'}. Best is trial 1 with value: 0.9766010241340217.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,413] Trial 6 finished with value: 0.9630944825171831 and parameters: {'scalers': 'standard', 'dim_red': None, 'knn_n_neighbors': 15, 'knn_metric': 'manhattan', 'knn_weights': 'uniform'}. Best is trial 1 with value: 0.9766010241340217.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,434] Trial 7 finished with value: 0.9633712456126249 and parameters: {'scalers': 'minmax', 'dim_red': None, 'knn_n_neighbors': 1, 'knn_metric': 'euclidean', 'knn_weights': 'distance'}. Best is trial 1 with value: 0.9766010241340217.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,455] Trial 8 finished with value: 0.976524117690938 and parameters: {'scalers': 'minmax', 'dim_red': None, 'knn_n_neighbors': 3, 'knn_metric': 'manhattan', 'knn_weights': 'distance'}. Best is trial 1 with value: 0.9766010241340217.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,493] Trial 9 finished with value: 0.9700624119098679 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 29, 'knn_n_neighbors': 15, 'knn_metric': 'minkowski', 'knn_weights': 'distance'}. Best is trial 1 with value: 0.9766010241340217.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,524] Trial 10 finished with value: 0.9766010241340217 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 26, 'knn_n_neighbors': 9, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 1 with value: 0.9766010241340217.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,552] Trial 11 finished with value: 0.9766010241340217 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 26, 'knn_n_neighbors': 9, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 1 with value: 0.9766010241340217.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,581] Trial 12 finished with value: 0.9766010241340217 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 21, 'knn_n_neighbors': 9, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 1 with value: 0.9766010241340217.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,615] Trial 13 finished with value: 0.973746568519168 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 12, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 1 with value: 0.9766010241340217.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,641] Trial 14 finished with value: 0.9767926035049322 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 24, 'knn_n_neighbors': 11, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,689] Trial 15 finished with value: 0.9741093462405596 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 14, 'knn_n_neighbors': 13, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,716] Trial 16 finished with value: 0.9767926035049322 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 22, 'knn_n_neighbors': 11, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,746] Trial 17 finished with value: 0.9754136895516204 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 18, 'knn_n_neighbors': 13, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,776] Trial 18 finished with value: 0.9726341109840299 and parameters: {'scalers': 'standard', 'dim_red': 'PCA', 'pca_n_components': 23, 'knn_n_neighbors': 11, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,826] Trial 19 finished with value: 0.9645117319994168 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 10, 'knn_n_neighbors': 11, 'knn_metric': 'manhattan', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,853] Trial 20 finished with value: 0.9764862945465653 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 28, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,886] Trial 21 finished with value: 0.9764862945465653 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 23, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'distance'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,913] Trial 22 finished with value: 0.9767926035049322 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 24, 'knn_n_neighbors': 11, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,943] Trial 23 finished with value: 0.9767926035049322 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 18, 'knn_n_neighbors': 11, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:23,973] Trial 24 finished with value: 0.9740163738685904 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 30, 'knn_n_neighbors': 15, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,002] Trial 25 finished with value: 0.9754136895516204 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 21, 'knn_n_neighbors': 13, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,026] Trial 26 finished with value: 0.9767926035049322 and parameters: {'scalers': 'minmax', 'dim_red': None, 'knn_n_neighbors': 11, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,056] Trial 27 finished with value: 0.9726559581860208 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 26, 'knn_n_neighbors': 17, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,107] Trial 28 finished with value: 0.9710162045179682 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 16, 'knn_n_neighbors': 5, 'knn_metric': 'euclidean', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,133] Trial 29 finished with value: 0.975207621414518 and parameters: {'scalers': 'standard', 'dim_red': 'PCA', 'pca_n_components': 21, 'knn_n_neighbors': 5, 'knn_metric': 'manhattan', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,162] Trial 30 finished with value: 0.976507193498319 and parameters: {'scalers': 'standard', 'dim_red': 'PCA', 'pca_n_components': 24, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,191] Trial 31 finished with value: 0.9767926035049322 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 18, 'knn_n_neighbors': 11, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,219] Trial 32 finished with value: 0.9767926035049322 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 20, 'knn_n_neighbors': 11, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,248] Trial 33 finished with value: 0.9754136895516204 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 16, 'knn_n_neighbors': 13, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,277] Trial 34 finished with value: 0.9766010241340217 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 27, 'knn_n_neighbors': 9, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,307] Trial 35 finished with value: 0.9754136895516204 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 23, 'knn_n_neighbors': 13, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,342] Trial 36 finished with value: 0.9767926035049322 and parameters: {'scalers': 'minmax', 'dim_red': None, 'knn_n_neighbors': 11, 'knn_metric': 'euclidean', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,381] Trial 37 finished with value: 0.9739762381141691 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 9, 'knn_n_neighbors': 15, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,405] Trial 38 finished with value: 0.9683866054093464 and parameters: {'scalers': 'standard', 'dim_red': None, 'knn_n_neighbors': 9, 'knn_metric': 'manhattan', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,436] Trial 39 finished with value: 0.9740163738685904 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 17, 'knn_n_neighbors': 17, 'knn_metric': 'euclidean', 'knn_weights': 'distance'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,482] Trial 40 finished with value: 0.9713505711663482 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 24, 'knn_n_neighbors': 11, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,504] Trial 41 finished with value: 0.9767926035049322 and parameters: {'scalers': 'minmax', 'dim_red': None, 'knn_n_neighbors': 11, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,526] Trial 42 finished with value: 0.9741258245053661 and parameters: {'scalers': 'minmax', 'dim_red': None, 'knn_n_neighbors': 13, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,549] Trial 43 finished with value: 0.9766010241340217 and parameters: {'scalers': 'minmax', 'dim_red': None, 'knn_n_neighbors': 9, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,575] Trial 44 finished with value: 0.9767926035049322 and parameters: {'scalers': 'minmax', 'dim_red': None, 'knn_n_neighbors': 11, 'knn_metric': 'minkowski', 'knn_weights': 'distance'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,600] Trial 45 finished with value: 0.9766010241340217 and parameters: {'scalers': 'minmax', 'dim_red': None, 'knn_n_neighbors': 9, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,619] Trial 46 finished with value: 0.9658339566852285 and parameters: {'scalers': 'minmax', 'dim_red': None, 'knn_n_neighbors': 15, 'knn_metric': 'manhattan', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,644] Trial 47 finished with value: 0.9741258245053661 and parameters: {'scalers': 'minmax', 'dim_red': None, 'knn_n_neighbors': 13, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,678] Trial 48 finished with value: 0.9766010241340217 and parameters: {'scalers': 'minmax', 'dim_red': 'PCA', 'pca_n_components': 22, 'knn_n_neighbors': 9, 'knn_metric': 'euclidean', 'knn_weights': 'distance'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,712] Trial 49 finished with value: 0.9726341109840299 and parameters: {'scalers': 'standard', 'dim_red': 'PCA', 'pca_n_components': 25, 'knn_n_neighbors': 11, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 14 with value: 0.9767926035049322.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,764] Trial 50 finished with value: 0.9794225452738171 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 14, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,812] Trial 51 finished with value: 0.9794225452738171 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 14, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,858] Trial 52 finished with value: 0.967931481959247 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 12, 'knn_n_neighbors': 3, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,906] Trial 53 finished with value: 0.9794225452738171 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 14, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:24,962] Trial 54 finished with value: 0.9765864924377645 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 13, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,010] Trial 55 finished with value: 0.969579422908773 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 15, 'knn_n_neighbors': 5, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,061] Trial 56 finished with value: 0.9738640057487483 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 10, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,105] Trial 57 finished with value: 0.968266882352928 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 8, 'knn_n_neighbors': 7, 'knn_metric': 'manhattan', 'knn_weights': 'distance'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,150] Trial 58 finished with value: 0.9681423847696072 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 14, 'knn_n_neighbors': 3, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,194] Trial 59 finished with value: 0.9606369545358341 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 6, 'knn_n_neighbors': 1, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,264] Trial 60 finished with value: 0.9736467575936116 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 12, 'knn_n_neighbors': 5, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,303] Trial 61 finished with value: 0.9780054456044738 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 18, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,354] Trial 62 finished with value: 0.9794225452738171 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 14, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,401] Trial 63 finished with value: 0.9794225452738171 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 14, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,448] Trial 64 finished with value: 0.9794225452738171 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 14, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,494] Trial 65 finished with value: 0.9794225452738171 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 14, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,543] Trial 66 finished with value: 0.9723581669895847 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 14, 'knn_n_neighbors': 5, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,594] Trial 67 finished with value: 0.9723064312532852 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 11, 'knn_n_neighbors': 5, 'knn_metric': 'euclidean', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,641] Trial 68 finished with value: 0.9780054456044738 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 15, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,699] Trial 69 finished with value: 0.9765864924377645 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 13, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,738] Trial 70 finished with value: 0.969579422908773 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 15, 'knn_n_neighbors': 5, 'knn_metric': 'minkowski', 'knn_weights': 'distance'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,780] Trial 71 finished with value: 0.9794225452738171 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 17, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,827] Trial 72 finished with value: 0.9765864924377645 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 13, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,870] Trial 73 finished with value: 0.9794225452738171 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 17, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,919] Trial 74 finished with value: 0.969579422908773 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 15, 'knn_n_neighbors': 5, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:25,957] Trial 75 finished with value: 0.9794225452738171 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 16, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,009] Trial 76 finished with value: 0.9711649135442914 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 11, 'knn_n_neighbors': 9, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,063] Trial 77 finished with value: 0.9686456978458766 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 14, 'knn_n_neighbors': 9, 'knn_metric': 'manhattan', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,102] Trial 78 finished with value: 0.9681423847696072 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 17, 'knn_n_neighbors': 3, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,149] Trial 79 finished with value: 0.9765864924377645 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 13, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,192] Trial 80 finished with value: 0.9726004100270245 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 19, 'knn_n_neighbors': 9, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,235] Trial 81 finished with value: 0.9794225452738171 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 17, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,275] Trial 82 finished with value: 0.9794225452738171 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 16, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,328] Trial 83 finished with value: 0.9513319987103642 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 2, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,378] Trial 84 finished with value: 0.9723581669895847 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 14, 'knn_n_neighbors': 5, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,422] Trial 85 finished with value: 0.9726004100270245 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 19, 'knn_n_neighbors': 9, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,469] Trial 86 finished with value: 0.9723064312532852 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 11, 'knn_n_neighbors': 5, 'knn_metric': 'euclidean', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,510] Trial 87 finished with value: 0.9794225452738171 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 16, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,561] Trial 88 finished with value: 0.9683875376634672 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 12, 'knn_n_neighbors': 9, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,590] Trial 89 finished with value: 0.9765645418079112 and parameters: {'scalers': 'standard', 'dim_red': 'PCA', 'pca_n_components': 15, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'distance'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,626] Trial 90 finished with value: 0.9779271241340208 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 17, 'knn_n_neighbors': 5, 'knn_metric': 'manhattan', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,671] Trial 91 finished with value: 0.9794225452738171 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 16, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,720] Trial 92 finished with value: 0.9794225452738171 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 14, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,779] Trial 93 finished with value: 0.9765864924377645 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 13, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,819] Trial 94 finished with value: 0.9752276678266959 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 19, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,866] Trial 95 finished with value: 0.969579422908773 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 15, 'knn_n_neighbors': 5, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,909] Trial 96 finished with value: 0.9739977257100545 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 18, 'knn_n_neighbors': 9, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,950] Trial 97 finished with value: 0.9794225452738171 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 16, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:26,997] Trial 98 finished with value: 0.9712402567703196 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 14, 'knn_n_neighbors': 9, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# C:\Users\sager\AppData\Local\Temp\ipykernel_22576\1135814593.py:39: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   knn_n_neighbors=trial.suggest_int("knn_n_neighbors", 1, 19, 2)
# [I 2024-11-25 17:12:27,047] Trial 99 finished with value: 0.975169392768421 and parameters: {'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 12, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}. Best is trial 50 with value: 0.9794225452738171.
# FrozenTrial(number=50, state=1, values=[0.9794225452738171], datetime_start=datetime.datetime(2024, 11, 25, 17, 12, 24, 712543), datetime_complete=datetime.datetime(2024, 11, 25, 17, 12, 24, 763540), params={'scalers': 'robust', 'dim_red': 'PCA', 'pca_n_components': 14, 'knn_n_neighbors': 7, 'knn_metric': 'minkowski', 'knn_weights': 'uniform'}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'scalers': CategoricalDistribution(choices=('minmax', 'standard', 'robust')), 'dim_red': CategoricalDistribution(choices=('PCA', None)), 'pca_n_components': IntDistribution(high=30, log=False, low=2, step=1), 'knn_n_neighbors': IntDistribution(high=19, log=False, low=1, step=2), 'knn_metric': CategoricalDistribution(choices=('euclidean', 'manhattan', 'minkowski')), 'knn_weights': CategoricalDistribution(choices=('uniform', 'distance'))}, trial_id=50, value=None)

# %%
study.best_trial.params
# Out:
# {'scalers': 'robust',
#  'dim_red': 'PCA',
#  'pca_n_components': 14,
#  'knn_n_neighbors': 7,
#  'knn_metric': 'minkowski',
#  'knn_weights': 'uniform'}

# %%
study.best_trial.value
# Out:
# 0.9794225452738171
